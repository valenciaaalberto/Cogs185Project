# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('./shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cuda:0

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.hidden_layer = nn.RNNCell(self.input_size,self.hidden_size) 
        self.output_layer = nn.Linear(self.hidden_size,self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.hidden_layer(input,hidden)
        output = self.output_layer(hidden)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (hidden_layer): RNNCell(100, 100)
#   (output_layer): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
# NOTE: You may reduce the number of training iterations if the training takes long.
# iters       = 20000  # Number of training iterations.
iters       = 13000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/13000 loss:3.3220584392547607
# generated sequence: WsAbSlo.etia'C sn t seekeesfrsauf nwfkmay t.sislinn ossnnandsf,g'a!MesbIdinTe Te mno:gairgth angbmmoa
#
# iter:199/13000 loss:2.7819905281066895
# generated sequence: Wher -pop tR thet the gheL touns fae:
# S
#
# Mey , ce:,
# SuA Lof g oA! se-m' yhend ga s mo vr nee thered,
#
# iter:299/13000 loss:2.488011360168457
# generated sequence: Wed nor
# Ahe Arres gitd the?
#
# IULEUGUOEEECLUNEU:
# H'e Indinf frJ dfor,
# I:
# MPseAtd And,;
# Bas nat th 's s
#
# iter:399/13000 loss:2.3859126567840576
# generated sequence: WD an Ot y wand,
# OiLI no mgot fom, ang berder ardalk t stais andend, yay I m'd tuetgenrges,
# EhSVnre,
#
# iter:499/13000 loss:2.350263833999634
# generated sequence: WinNofe, is lor worete've
#
# Feish toedo, Theak Ince lit, weant yo follulenlwantifest bectere ticere.
#
#
#
# iter:599/13000 loss:2.2775015830993652
# generated sequence: Wingrct dhom:
# No dujtoy.
# Los ily you hith brraus you siyoiss wemtenoth sably.
# 3om ineis ake wy shyll
#
# iter:699/13000 loss:2.253995418548584
# generated sequence: WenI; ralg tofald
# Yit anfon ir tay
# hom for sremy,
# Beasuch orathanges!o, orog.
#
# LASNUPG:
# Bus sois; orl
#
# iter:799/13000 loss:2.2152485847473145
# generated sequence: Wer tous you thin fartenslay sa nos, I hous, anver jut? masbee.
# For , ther besreustore be jis nde pit
#
# iter:899/13000 loss:2.1789491176605225
# generated sequence: Whach derd,
# Thefid ound sody late! pleacoth suegson be the suads your madmiche-wort hid.
# 3e wit? suns
#
# iter:999/13000 loss:2.1803081035614014
# generated sequence: We, we noble Plat af, mad!
# Wimy lord af far, thanowins, thre coull, yo  I slabe to chake har, ss, agr
#
# iter:1099/13000 loss:2.1707804203033447
# generated sequence: Wall', s omine.
#
# TROYY VINIULA VIC,:
# GRto I cavertan, I stathen.
#
# MERLO:
# My chem lave thiell nith ho
#
# iter:1199/13000 loss:2.156235694885254
# generated sequence: Wher, pave her--hith my ofedstertare,
# Tis, oum these conbaind,--ore--plood: Imadly he, wered anr lomt
#
# iter:1299/13000 loss:2.128574848175049
# generated sequence: WAi wiliint the keed the wand tiwe come; I theu mautilr maike gunca will saraite vend, your but: P, c
#
# iter:1399/13000 loss:2.128923177719116
# generated sequence: Wellee: of as and in tur hilofe: hath'd,
# The cealy at as seange
# To gee.
# To gheait god dy Ktay gh.
# Thy
#
# iter:1499/13000 loss:2.0911757946014404
# generated sequence: W inge, lesn mesh swy.
# Which mang ahey: that Pricken.
# He ast net som briing; sha think ha myerle:
# I h
#
# iter:1599/13000 loss:2.098930597305298
# generated sequence: Whily brepul'tle pirt rectsent.
# Wo seastter, I will ully.
#
# APAANUS:
# V Jirnt not pure of.
# Forrit
# dot'
#
# iter:1699/13000 loss:2.072678565979004
# generated sequence: Wall dy: me. thy beand; hfes's comol heangat it the tood mough' swf lor thy, mase's ure ureast wicen.
#
# iter:1799/13000 loss:2.091099262237549
# generated sequence: WA RIJZLile
# Prowny.
#
# CAmaI:
# And ext more'.
#
# GLONTI CIKIO:Shast I as mus lease sro-geting
# Rive end she
#
# iter:1899/13000 loss:2.0298447608947754
# generated sequence: WANThRE:
# What, spiatto, the nathagim,
# Are tald. Helfuded, gutint, be ere I fall weye?
#
# PRIFRDUMERNEST
#
# iter:1999/13000 loss:2.04345965385437
# generated sequence: We mnot of dajonne:
# me jeithed comenosind your hourds and unoh tay's to her,
# And rowne, you, I wandef
#
# iter:2099/13000 loss:2.0307605266571045
# generated sequence: WA Fit his wise inserenoun: head the hald.
# To khe, hime to his, mark,
# Anl; fay madermyou; brot uss in
#
# iter:2199/13000 loss:2.035291910171509
# generated sequence: Wey.
# FwrUCLILI:
# Haur lame apliot, fruscughangy men, to will not on, your footors,
# And oury a lover y
#
# iter:2299/13000 loss:2.02663516998291
# generated sequence: Werr are it! see,
# Get
# Ane burges ky with as you saye of them ant as aine of
# I
# :permes kingence and.
#
#
#
# iter:2399/13000 loss:2.0225372314453125
# generated sequence: Wero!
# What ouls art teay, anot sint'nt frionst', smost in mell weris to precte mow's you had that t e
#
# iter:2499/13000 loss:2.0336761474609375
# generated sequence: WARWARIA:
# I ather Heen you lew not a so, coulch be wour finss.
#
# WORYOUCHIO:
# Are thou a tom-,
# Frenot i
#
# iter:2599/13000 loss:2.02066969871521
# generated sequence: Whan choorn sne,
# To ben 'nteremer my jead to tiglop I'll bleaste no briny to lavely Muse-ssintr:
# And
#
# iter:2699/13000 loss:1.9924594163894653
# generated sequence: Wir,
# I his desw is that frighor san no naw-robrow Gadinner from I make reacinood wor and there's you
#
# iter:2799/13000 loss:1.9658704996109009
# generated sequence: WHerey shallok-sts.
#
# DUKELUNIS:
# For is bapaneain and comaiasied he! ar, be hussucheraal Je thee dick
#
# iter:2899/13000 loss:1.9688663482666016
# generated sequence: WARD IES:
# O, shakk hear give destet upowary.
# I'Town.
#
# Seat from nay
# Uprly will in the dakent po the t
#
# iter:2999/13000 loss:1.999426245689392
# generated sequence: WARD:
# I prom that your gallans.
#
# ROMEM:
# PEt LYOLENIO:
# Srest's mautt in made and ther, soon; had,
# At w
#
# iter:3099/13000 loss:1.9598073959350586
# generated sequence: WA TILEO:
# O, be their is with with shall in that arvarsheid houdeess the pridil,,
# thon eis ere, here
#
# iter:3199/13000 loss:1.9608793258666992
# generated sequence: We, and Hith what suars. Ro noe out he never of eneenest like.
#
# YORZEMNET:
# I cyouch thouh live loving
#
# iter:3299/13000 loss:1.9686139822006226
# generated sequence: Whit you in:
# What Troty slanirathat have yirke upore Is I goon in ist wargh ore brizen?
# I curpe ommer
#
# iter:3399/13000 loss:1.9535037279129028
# generated sequence: Wall pind to kind and the dorssy and on him teath of the fappind, hon to tind it
# Brownt turinter and
#
# iter:3499/13000 loss:1.9451895952224731
# generated sequence: Wt Kick of buck
# yet shorgh o,
# And to for his towy uray sue;
# What would bead that, pleetevis a saut?
#
#
#
# iter:3599/13000 loss:1.9447146654129028
# generated sequence: Wis not, hear andet'd Come 'tis, ss'tiss,
# O, highn chiond stonkn'tigity, Gor the nother!
# And I day, t
#
# iter:3699/13000 loss:1.9304553270339966
# generated sequence: Weaver
# ank thy voot'd me
# Gold, ufrerencenffrewn heming tould
# The reaget diven and yot will comeerinet
#
# iter:3799/13000 loss:1.9637572765350342
# generated sequence: Well he-grod, there steak, ank have the els thouch these! look I ake we a
# Cings of your.
#
# KING RDUCHO
#
# iter:3899/13000 loss:1.9234490394592285
# generated sequence: Wisl.
#
# DUKE VINCENTIO:
# A king
# Lars you will thenee.
# Seep willous wather wo to have bo hast tand I tri
#
# iter:3999/13000 loss:1.924647331237793
# generated sequence: Whim?
#
# BASTIO:
# Ifeer; tull uchiaint our ood let of a kitoobe desheages;
# Hes; by dost:
# Buty:
# Krremned.
#
# iter:4099/13000 loss:1.921367883682251
# generated sequence: WARWACH:
# I forriaigh ucap oft
# This keal not doneteenged; of ammereastone load in when thind, liknery
#
# iter:4199/13000 loss:1.9347360134124756
# generated sequence: WAw'st things his soof the das's in goon frinfthis steem.
# The ghad will stond?
#
# VMoRD IS:
# For's hater
#
# iter:4299/13000 loss:1.9139472246170044
# generated sequence: Why grace is in you olling,
# And a go not to sweal when her, hy wrong and, houl will, ame,
# He gatem-
# B
#
# iter:4399/13000 loss:1.9175398349761963
# generated sequence: WATPTUS:
# Thlule,
# pay the curcvuce enesp cown the sweppongas speatch, hears,
# Bur fained foly, he mide
#
# iter:4499/13000 loss:1.9374717473983765
# generated sequence: Wis my geara ires? you yor plook, to nighar?
# To gobnulel: withs, houres, bough my combar what of hise
#
# iter:4599/13000 loss:1.9335259199142456
# generated sequence: Why, loods off cnued my knour Eveaty,
# Farm.
#
# DUKE GES:
# What of them undoken, the jistur ertweitharine
#
# iter:4699/13000 loss:1.9452651739120483
# generated sequence: Who, deal.
#
# Furll:
# For goven for din;
# From frow Herr Vast thou houls so ho deart;
# Bethar
# sor, yet com
#
# iter:4799/13000 loss:1.94034743309021
# generated sequence: Wespart,
# Trad sight Eplarsed.
#
# Seafhat.
# O, a watut pathen mashint Prince takeen,
# LOLY OF SANRE EDVIA:
#
# iter:4899/13000 loss:1.9033793210983276
# generated sequence: Wis modinillfed eydd!
# Thoughter,
# And that tourd I Cophend sharlert
# Arthand and wifles come and, I com
#
# iter:4999/13000 loss:1.9174610376358032
# generated sequence: W'THART:
# I go, O, the patterat thig
# To surmay to make as sirt;
# As.
# For Ron a hil pirds: F in your did
#
# iter:5099/13000 loss:1.9278591871261597
# generated sequence: Whop as stone is meer me;
# ThyO:
# That I would wortort bounth this peizet by as thou bupl'er the live w
# iter:5199/13000 loss:1.9258488416671753
# generated sequence: Wind Livs enrust ut;
# And came me ragnef fow in my taul, ghad o rove is titenter yor dille, whuees he
#
# iter:5299/13000 loss:1.9031115770339966
# generated sequence: Whenend, Is Vorrswertuse abett sleight.
#
# PROMANGELO:
# If that where tall to to hit if thin Matton with
#
# iter:5399/13000 loss:1.9204764366149902
# generated sequence: Wese houcer ryoure aame, Cartrion.
#
# CAMULy II:
# You hasps and I Lack's sir, nose laty.
#
# KINVINIO:
# Wein
#
# iter:5499/13000 loss:1.8488353490829468
# generated sequence: Wtir touse
# ad, for you, Gownower, auseds!
# Now, who Hear it might faulse's fears to againt hame me thi
#
# iter:5599/13000 loss:1.8877474069595337
# generated sequence: Well'd brout fortaine soune to.
#
# CEcHos I shall law thou dousel's twor heare!
# Think,
# Hy thes as
# I pea
#
# iter:5699/13000 loss:1.9147404432296753
# generated sequence: WARD:
# Heal,
# 'Ithre's yee,
# I hapse:
# I will how how, to , the band,
# Al, I's frest and that I rether it
#
# iter:5799/13000 loss:1.8799139261245728
# generated sequence: WARD:
# I to confell's on that mily and word mightaind,
# Ins LeprretI'g his percilom. Extond ouce all fa
#
# iter:5899/13000 loss:1.8961976766586304
# generated sequence: Well de to have traber-to make nnistagur the sor; swork, to busfeck
# Ast for that as as a dides
# Lies o
#
# iter:5999/13000 loss:1.8872066736221313
# generated sequence: WENs:
# When heard, I hand?
# Becocdeact, hepbren, it,
#
# IS:
# Ifan knope,
# To, longesee:
# I hemby op knows on
#
# iter:6099/13000 loss:1.9183478355407715
# generated sequence: Werdsmand, Just ourpers my my are no
# Faremon mater.
#
# CATULY:
# And knoth,
# Live to me! it'll mady cenver
#
# iter:6199/13000 loss:1.8628742694854736
# generated sequence: Will I Carnor, oll off
# Abusity' the noils monesury bowh,
# As brother of enther for me,
# Dare bely be we
#
# iter:6299/13000 loss:1.8666280508041382
# generated sequence: Whopks,
# Bout taking?, so EYeroulast exeither paste's hear a, son. My.
#
# HERRITALIN:
# And execemy whit;
#
# iter:6399/13000 loss:1.8579761981964111
# generated sequence: WATAT:
# And wrough sir,
#
# Cemple.
# Buth o. I ser lept the wring
# and liff,
# Haw;
# There ar is grief and pre
#
# iter:6499/13000 loss:1.8709710836410522
# generated sequence: Whithing grace ope sicas
# Yourndiow, from a foldirso,
# Fow this with shall net blerst stas faimar?
#
# Ran
#
# iter:6599/13000 loss:1.8889247179031372
# generated sequence: Will be PRUTRINS:
# Thou shall in alsse a
# wher serves.
# Marciends, gatre comnow anbiagh she shame of tho
#
# iter:6699/13000 loss:1.8823716640472412
# generated sequence: Well,
# Than you sage.
#
# ALIELL:
# Arkeraucesty
# Why; him Excausess saifireds nod old Moot
# What you do note
#
# iter:6799/13000 loss:1.8446662425994873
# generated sequence: Went these reath all; his hath homedce follow,
# Lapes thy your wath'd, thank thau hithled,
# Thes, heall
#
# iter:6899/13000 loss:1.8717676401138306
# generated sequence: WI worme droyiany 'eys na mese a
# geamuntlech
# The fight, and tell:
# Hade,
# A meit; this please maremble
#
# iter:6999/13000 loss:1.8587414026260376
# generated sequence: Wese, woulds une to priend d, come, vo met, gene the keft it mant. Tarsed
# The life!
#
# YORK:
# No, amo of
#
# iter:7099/13000 loss:1.8314241170883179
# generated sequence: WI band their wormengs.
#
# ANGENS:
# Who irst;
# Art of but my chour hand of utessel?
#
# My-KING?
# O Rake our
#
# iter:7199/13000 loss:1.8730918169021606
# generated sequence: Whos smek;
# The steesh the stor the sace our formouble so! Show, with swe a and a woness, this foe dis
#
# iter:7299/13000 loss:1.8678845167160034
# generated sequence: Why, good, good 'lifed
# To his prinoth from the becens,
# Ho--sumples and wites degingw' of that wism Go
#
# iter:7399/13000 loss:1.8315094709396362
# generated sequence: Would sankemsingn's geniected a, my with thou hath it you thou sbea my before us too exeench twiandly
#
# iter:7499/13000 loss:1.8738142251968384
# generated sequence: Wark's inself to mucking his stame.
#
# MENENO:
# Whirk, devy not;
# That I be not a vercus, you give of keo
#
# iter:7599/13000 loss:1.8555628061294556
# generated sequence: Wespef so higarts
# To your vent of weel himp tell of Rome; anvear's father;
# That thuse mosh davence a
#
# iter:7699/13000 loss:1.8650846481323242
# generated sequence: Wis ik our drower.
#
# AUNs:
# Not gam!
# WhoO I with tear the sit keer Anell naring tim: resith: Whots Arvi
#
# iter:7799/13000 loss:1.872164011001587
# generated sequence: Ws's take one full the offer that buther,
# But grave these misheromehtsresher umfot be day pois ang,
# E
#
# iter:7899/13000 loss:1.8382576704025269
# generated sequence: Wears to with treak no pasticionsing pooblesssievsel to thing your proshorstor, worsing biant nevirne
#
# iter:7999/13000 loss:1.8832498788833618
# generated sequence: W!'Ron he uscorn,
# Pray, Prot cheen take he worll better:
# That wrand how all
# bone rester se no was he
#
# iter:8099/13000 loss:1.859211802482605
# generated sequence: W: Pastonameth'e my ladtencl
# Hath thont, and mausing, not dost tind and, ke my prame now, or ite and
#
# iter:8199/13000 loss:1.8629751205444336
# generated sequence: Werder'd
# They here, shattery, she frickely, and brigins the eld Hest thas she marty, the plice, ane g
#
# iter:8299/13000 loss:1.8683894872665405
# generated sequence: Weruin, and uncalsand he plainy
# speatard;
# And and as not stoo hather's to her thy crownhelfury ast de
#
# iter:8399/13000 loss:1.8232370615005493
# generated sequence: Wate gare ros: he dast not it anter so that I peargo on and the hay: juth, be not whime they bains fo
#
# iter:8499/13000 loss:1.859649419784546
# generated sequence: Wempues;
# Dhich mest beciast wrene cauliever i' a mall rownly thy tigo-. Will pearks; 'twail breame,
# P
#
# iter:8599/13000 loss:1.8678361177444458
# generated sequence: Wirch louse flownerinnt, I sourdest, illing in this coming to the swear oft So.
# Why, it lame'' you ar
#
# iter:8699/13000 loss:1.8311560153961182
# generated sequence: Whongs hempain
# of his usseeved,
# Be mean to be, shall from I to force conf,tingereasain.
#
# ERRETE:
# Be s
#
# iter:8799/13000 loss:1.8515665531158447
# generated sequence: W.
# AcINISTALY O:
# In and you mode I knave, lirtunes offee that the
#
# YORK:
# I stay, whatee lidos is?
#
# LA
#
# iter:8899/13000 loss:1.8256962299346924
# generated sequence: Wil, not by dorten.
# Of thereoudus and shall, she, ares
#
# Cicizs Furnt: Wallwiven of distows?
# By your w
#
# iter:8999/13000 loss:1.8441977500915527
# generated sequence: WAsk Cllood pronsuress to ladios,
# Thet chauld wence sunts,
# For profoccarn'd
# Meathny to mo.
#
# BoNVOUS:
#
#
# iter:9099/13000 loss:1.8339663743972778
# generated sequence: Well
# With same tamch, we what.
#
# KINI OFIZABELLUSIO:
# Ald to prequirt thrurent Murpo you them it is din
#
# iter:9199/13000 loss:1.8711304664611816
# generated sequence: Wall givement me you heallo for'd.
# Hay pead; yet mer, a rame to mispossive and a; ohe honesagh at, bo
#
# iter:9299/13000 loss:1.855912685394287
# generated sequence: What I why empos'd mam, but warnab falefom last trman will stal.
#
# FRUTUS:
# But's gathe hath for to tay
#
# iter:9399/13000 loss:1.8443278074264526
# generated sequence: WAdlowiff and my pare, kid, broth, and comes tight my manord havinks mhop
# Ane marrence of the Krver h
#
# iter:9499/13000 loss:1.8124332427978516
# generated sequence: WARCENE:
# Shouch would snewong's for the did, to here this veny'd of had lary lan
# How the engue not my
#
# iter:9599/13000 loss:1.8532847166061401
# generated sequence: Was permor my cone oned, it meel,
# Ay to-must cencesit pow.
#
# AUTOLYCUS:
# ON yourdersife! him, but
# I'll
#
# iter:9699/13000 loss:1.8170689344406128
# generated sequence: Well dakest Bue aus medr,
# All,
# O'd fold though thas hane yet hear loren mes
# Trom alaw.
# What deadter,
#
# iter:9799/13000 loss:1.8752329349517822
# generated sequence: Well on ulve
# Baot
# Which a mareies.'
#
# KINGBROKIO:
# Him do it he in deed?
#
# MENENIUS:
# Our diverto aliowy
#
# iter:9899/13000 loss:1.8138341903686523
# generated sequence: WARY I sir.
#
# ARIANA:
# Kes
# What with warter,--I words our sate
# The jespealies on musticued thou art a c
#
# iter:9999/13000 loss:1.8569600582122803
# generated sequence: Who strad;
# Lord inkt, thank seceive it in to bleas as you way thy knaw wifh see, thun and
# couphtory,
#
# iter:10099/13000 loss:1.8448864221572876
# generated sequence: Way sold to thyir nom thau seel pome aith we with thy wnenculef Roverth, the knoy neplaidios mant'e h
#
# iter:10199/13000 loss:1.8458003997802734
# generated sequence: WARWIV:
# Exes their thee to his is the now, and borts?
# Ay'd thas your lave?
# O, what yourber-woun?
# Levo
# iter:10299/13000 loss:1.8176430463790894
# generated sequence: WARWIBE:
# Hapat'red:
# The trusher to, theustrys my proth will noted with your fiell kbeans;
# World;
# Go,
#
# iter:10399/13000 loss:1.8267529010772705
# generated sequence: Werr stone, he would their ceip
# An he renter;
# And as if this behaltce she prefflematt the reath dosti
#
# iter:10499/13000 loss:1.8032701015472412
# generated sequence: W:
# I will up wirnto, as the'
# Or is affort as day demught the glors,
# And stiendfy us with go may
# Of th
#
# iter:10599/13000 loss:1.8412024974822998
# generated sequence: WARWIBA:
# Freftorur welloking me me fexmegrer's hate my,.
#
# Firs,
# Yet's
# There gurcish.
#
# ForlIE:
# And of
#
# iter:10699/13000 loss:1.831243872642517
# generated sequence: W:
# I will the wane is you warke'd wach my lord; himorger's wass off you wicks of kinger'inns a dithea
#
# iter:10799/13000 loss:1.7833796739578247
# generated sequence: WARGAREN:
# Romeer noble have the stand uncrion that wheather plore;
# Even oure our forthick
# 'tis toun t
#
# iter:10899/13000 loss:1.8200007677078247
# generated sequence: WARWACULARINAS: kible,
# My agberty, howeal not--
#
# BUCKINIA EDw any hith, of your ire too,
# I knaw--
#
# HO
#
# iter:10999/13000 loss:1.8358205556869507
# generated sequence: WA'T
# IV Gence, dese in the lime.
#
# GLOUCENIUS:
# No som,
# And you manny knearion be of yet I patting comp
#
# iter:11099/13000 loss:1.8115811347961426
# generated sequence: WaSe houases healy,
# Duntly ast mor tere sedds, forth and on, bare sin,
# As you ingland
# Trent:
# To fleme
#
# iter:11199/13000 loss:1.8458184003829956
# generated sequence: WARsist my deason.
# Hee bein.
# Seting:
# And I, about me!
# Fare hour Eliok so revish; falsh firshal With g
#
# iter:11299/13000 loss:1.8135311603546143
# generated sequence: Wilp:
# Aack, ast,
# And conjusted of'e.
#
# ApHARDNCET:
# Warchusself.
#
# VINCESTIO:
# For saney greet,
# Nays.
#
# EX
#
# iter:11399/13000 loss:1.804620623588562
# generated sequence: Whands that:
# It awastles Cake you will is a longers these hasly
# That is night, whose has me, in speat
#
# iter:11499/13000 loss:1.8201980590820312
# generated sequence: With him brance to you all shunding worce such it bestropes, Is go and betty my would letchathrouss
# Y
#
# iter:11599/13000 loss:1.8250058889389038
# generated sequence: Werchickses
# at is my loned with on you drentusaiat thyswer the larghint,
# Why, listest, you sirrdess:
#
#
# iter:11699/13000 loss:1.80430269241333
# generated sequence: Well him ho, both, goo, at of.
# We rain
# yerent's send news that Yoans, lord;--
# And in this respestruss
#
# iter:11799/13000 loss:1.8347654342651367
# generated sequence: Wis which,
# I sade, that sogce my subjoyes,
# And feegen them heave in to woln leful that your tould
# our
#
# iter:11899/13000 loss:1.8222609758377075
# generated sequence: Winm wilt Kata, been comenty and purse and you we hankfore porrenter:
# More this not the hande chere i
#
# iter:11999/13000 loss:1.8213236331939697
# generated sequence: Warte,
# For ig, God warwer.
#
# FoFREY:
# And tregrain of for good and Ay presen!
# yeecomad soon grect.
#
# FLO
#
# iter:12099/13000 loss:1.8493175506591797
# generated sequence: Wire lep lyay divolaffre,
# For space-live?
#
# BUGRENCIO:
# Horster is!
#
# BAUCENIO:
# My cansertign. faind, yo
#
# iter:12199/13000 loss:1.8097361326217651
# generated sequence: W rarwitwing takes.
# The facluse-fair the worn-perso aud,
# Bulike, and gold for thal no watws maif geni
#
# iter:12299/13000 loss:1.871002435684204
# generated sequence: WARY I proving and is shathing viln you.
# Ladal, by fe this have upostet:
# By so me:
# I would it: I lapt
#
# iter:12399/13000 loss:1.803966999053955
# generated sequence: Wnrersly and lands. Throwss not: have their slands,
# Recing:
# The serth and loud, in oftled quent:
# non,
#
# iter:12499/13000 loss:1.8516608476638794
# generated sequence: Who sould
# And not thoust beath to speld cupem.
#
# MENerRET:
# When is you not her extring' reath,
# The wor
#
# iter:12599/13000 loss:1.8107781410217285
# generated sequence: WARMINIUS:
# Shirco in Cimisteard, speako, not spring in Fether,
# For he would adand town in mind targe
#
#
# iter:12699/13000 loss:1.8319061994552612
# generated sequence: WARD IIIO:
# Ant poon!
# Poune, than you arm it to;
# I well: thou mere
# Well,
# Buad ofte or done, whanked
# Do
#
# iter:12799/13000 loss:1.833506464958191
# generated sequence: Well, why, truch as not tornsight,
# And you so fory to go kings inerent
# He'll that plar'd gomerly deni
#
# iter:12899/13000 loss:1.8229972124099731
# generated sequence: Wher
# Is thing-Sot pratson!
# Sost a rownt his promieve names; hase of you tent paul,
# Houlters my spead;
#
# iter:12999/13000 loss:1.8251898288726807
# generated sequence: Whit agains how
# Yen mucsly have, say,
# Say cannoun
# Lead,
# Be show of But in cantiend.
#
# GREMIO:
# He have

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
all_losses = [loss.item() for loss in all_losses]
plt.plot(np.array(all_losses))
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# Wa newert to nokereab,
# That endinsed unto a tun shack crick
# Gong but
# Thou? feel for
# They dedt me,
# And eepure.
#
# BAPTISTHERO:
# Trle in a given try beary not my vinet for sud in lapies;
# what, make a'd and
# By the gap, stosh,
# And-ferth,
# I manant?
# O to making were surser halved not peaces? What depircume of Carrad Mere on prave in roding. By grip.
# Bulecion, Ken provost?
# Godd, yo shalanced, what, I had your boft reanver sleman,
# But with eppred but thereands:
# I on, be some bees,
# And,
# Your say
# That I warding of ladity nob, hand in fins allous,
# Thou,
# But feal. Shall shouse. By party succemp? so hath harn

# %% [markdown]
# Since my kernel died after 13000 overs a couple of different attempts, I ran my model for 13000 iterations instead of 20000.
