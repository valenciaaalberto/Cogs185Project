# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('../Data/shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cpu

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.hidden_layer = nn.RNNCell(self.input_size,self.hidden_size) 
        self.output_layer = nn.Linear(self.hidden_size,self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.hidden_layer(input,hidden)
        output = self.output_layer(hidden)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (hidden_layer): RNNCell(100, 100)
#   (output_layer): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
# Number of iterations.
iters       = 20000  # Number of training iterations.
print_iters = 200    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adam(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:199/20000 loss:3.069990873336792
# generated sequence: WUeit ninnce sood md At,
#
# om weub oulitire lf ceowndWNInwp
# TsiRNe?dind
# Lse Cin the hidlw:
# negeitd gry
#
# iter:399/20000 loss:2.504652976989746
# generated sequence: Wand
# WIOa:
# Iithe tifh as thour 'asethaskurd I
# Wour whrorr hordith wervon, th hot enols bondarite shi
#
# iter:599/20000 loss:2.3564858436584473
# generated sequence: Whilien ta mers saat be onozedeer endast ie with af?
#
# haem feanbeld anoiod abd's Yordine
# Anhest:
# Go G
#
# iter:799/20000 loss:2.324993848800659
# generated sequence: WeoI bumith the hor is fertarin with ut beam; theur this ther fhechior the you paomit byou im theisny
#
# iter:999/20000 loss:2.2393033504486084
# generated sequence: WFrce, yy hetuss no ksir
# and the sstusnd,
# Or,
# And if?
#
# QUCEIT:
# Chis suse
# Bu
# chants nonosge,
# Bardhor b
#
# iter:1199/20000 loss:2.199495315551758
# generated sequence: Why beverd notcridre?
#
# MEREMIO:
# Nice or blome that mere sur tsoorty:
# Thes that hy ar ghouly, an by la
#
# iter:1399/20000 loss:2.183084487915039
# generated sequence: Where y lom's, ard buchereard of le: ceot ant of woule,
# Kuthle.
#
# SUSRNON:
# Hor witeredabus you masts
# A
#
# iter:1599/20000 loss:2.1328322887420654
# generated sequence: Wilved'er's mumrmes do mistard, bearthie'det:
# Of Rildt at long then,
# Ondon:
# And hill on the kno-s
# NRE
#
# iter:1799/20000 loss:2.1192665100097656
# generated sequence: Why wings!
#
# INKEO:
# Dees nop as oulead, feren for I marte demert thembel?
#
# PERMROMILO:
# Ot
# AHAnk memint
#
# iter:1999/20000 loss:2.0771443843841553
# generated sequence: Whem hepblinate lompar hesers, ald man epory,
# Cnor hishersient sies
# Or ciffo, irst I lon ere the rirt
#
# iter:2199/20000 loss:2.0735585689544678
# generated sequence: WONDYY ERST:
# Why glikgell the roon.
#
# Forst lavly, if SI a muny come the graytelldy; me:,
# And soais de
#
# iter:2399/20000 loss:2.052628517150879
# generated sequence: Wis nothin plae wing, thes I castef.
# Whas illond'd?
#
# DUKE VINCENEEL:
# Hour have your tiderd!
#
# BENENTA:
#
# iter:2599/20000 loss:2.0540125370025635
# generated sequence: WAKULINGROUCELI:
# Ay fory:sen twat poofe asce to dein is cond
# Ifere:
# Then by my the reacoos your her,
#
#
# iter:2799/20000 loss:2.0195674896240234
# generated sequence: Wist dount Wille of Panuino.
#
# QUESNLOLES:
# Hy lunsm die parmins and duspe he her, it cortulat, pontus
#
# iter:2999/20000 loss:1.9983967542648315
# generated sequence: Will nis speckee, pespilare: frue of reall, his; than hame alting this hemen buf ford.
# But now! But k
#
# iter:3199/20000 loss:2.0049335956573486
# generated sequence: WFwarch then thorsell and mave. for hepllawo, a
# to thee, bidy,
# Oxceive. I siarsmy'l sene and spice ur
#
# iter:3399/20000 loss:2.0100443363189697
# generated sequence: WASY IANUl:
# Deave 'A layb;
# The batt a the rike a bald theed nige oure ed by trinor:
# Whicher gu be pet
#
# iter:3599/20000 loss:1.9907559156417847
# generated sequence: WAClow, my for as suathers, wasphand a'ds  intiness'T canster.
# I shead hirbinging will themou with sh
#
# iter:3799/20000 loss:1.9670710563659668
# generated sequence: WANh:
# Wall theld heroracghon to  hate ir hompnaiahtrd.
#
# JDINCK:
# To lid's nonetry fristy her herge!
# Sa
#
# iter:3999/20000 loss:1.9541751146316528
# generated sequence: Were for Guse tober, Thour come
# Wine our prusnel sir.
#
# GRUCHARIUS:
#
# TRISESIUCINTIS:
# And who creake we
#
# iter:4199/20000 loss:1.9436794519424438
# generated sequence: What thial at is all lime, than thipd
# an felm.
#
# EXEEN:
# He to so froog there Ruch exitnd, by a treptre
#
# iter:4399/20000 loss:1.956742525100708
# generated sequence: Who saithana is the pray, bursenor sath
# Gon more clows to should your coch done,
# Leid the knond:
# Hat
#
# iter:4599/20000 loss:1.938407301902771
# generated sequence: We will make will rome makes stremes
# 't hon youbenre with Winion fit to cheine me vwatle fard my worl
#
# iter:4799/20000 loss:1.9370559453964233
# generated sequence: Were I and tesiont.
#
# QUES MINVOLIO:
# So, musiey that aghars
#  hart I with in theur cadnating'd teoramen
#
# iter:4999/20000 loss:1.9069390296936035
# generated sequence: Whuck ount grought, how moven mimbrey so in then from sle mantering suers,
# Which of your land!
# Mad mo
#
# iter:5199/20000 loss:1.909395456314087
# generated sequence: Whrcetys she forthe when:
# Uut repes
# And recirt; an
# and to thee, not,
# The not on mist to and Eefith vi
#
# iter:5399/20000 loss:1.9130396842956543
# generated sequence: Whor I sorl'd bount;.
#
# PELAXET:
# Athust that would Sbe's bof theirleas mugh within is;
# At'nk,
# And new
#
# iter:5599/20000 loss:1.9150989055633545
# generated sequence: We are me to as:
# thelald we spall,
# To love of your you an lartant,
# Betessed be sparein's his secity t
#
# iter:5799/20000 loss:1.8970309495925903
# generated sequence: Wello, a dit's fith take
# Be, my horevy?
#
# Lirsf, beooir with jut you gruth For the yon be.
# One dis, hi
#
# iter:5999/20000 loss:1.8872534036636353
# generated sequence: Whough gulpoum, lodd geased an, mistent hath reccepien in no a, hath with! when mienate:
# But lord?r p
#
# iter:6199/20000 loss:1.9137699604034424
# generated sequence: With some a to bets on, not king you abue the grances mane and the for al the me but for you;--
# Izath
#
# iter:6399/20000 loss:1.8954379558563232
# generated sequence: Were you an roung tuthimshto ang.,
# Tttuse praftly un ca-time thee,
# And
# Mipcuut,
# Sour, with thy ulld,
#
# iter:6599/20000 loss:1.8716899156570435
# generated sequence: We kneke me, bar, my so are her way rigloge.
#
# PAUSLUMENCE:
# For Vie: word mire rest.;
# En and wake him,
#
# iter:6799/20000 loss:1.8843131065368652
# generated sequence: Whon mith meness good the gile, mata? but gobson my for have the rich sins.
# Will beebsa man me me God
#
# iter:6999/20000 loss:1.8824728727340698
# generated sequence: With alle must compraxch,
# O be not
# may with her wanto af of to to, the pricene mo;
# And with do, bure
#
# iter:7199/20000 loss:1.8653738498687744
# generated sequence: Were are:
# Where have the minrer of Werombefair if wick, crion.
#
# PEO TIUGREO:
# There, to-Muell'd
# Oree w
#
# iter:7399/20000 loss:1.8676257133483887
# generated sequence: Weam my woy-and a meantay one id hear maghte theast:
# Tierentting to sice; and nhaitines By, mains, pe
#
# iter:7599/20000 loss:1.8444746732711792
# generated sequence: Wetle by mad,
# Ay oneet there.
# Ir gree
# She of Loots you;
# Think 'tis nothing on hoor othaply, thou trou
#
# iter:7799/20000 loss:1.8641350269317627
# generated sequence: Weresse'd with wifbdows part to live, Is affict of the konow your puiel:
# And parrselfy,
# Thel,
# Pasther
#
# iter:7999/20000 loss:1.8454715013504028
# generated sequence: Waight'T:
# Becal knowns the call made up here hear we king.
# Tell.
# O lord: I yousen. Will so not your s
#
# iter:8199/20000 loss:1.831753134727478
# generated sequence: With from thou whou known is glastys.
#
# AUTILAMELLANE:
# With him.
#
# QUEEN ELIZABET:
# Yot, the him
# Rist in
#
# iter:8399/20000 loss:1.8858832120895386
# generated sequence: Weings warmd; He me!
#
# QUEEN ELIZABCIZABESHARD
# I ICKind not,
# If you sweal, come me
# Even mere-call than
#
# iter:8599/20000 loss:1.8660597801208496
# generated sequence: Werch, Theip under, I's my hing of strinting on make and nuriereignor, that as ull Home.
# To harth, no
#
# iter:8799/20000 loss:1.8623108863830566
# generated sequence: We you a farm'T:
# No sard think
# Took swettid of sere wwow Petwor Quet.
#
# Nurse:
# We are not frose, that.
#
# iter:8999/20000 loss:1.8836270570755005
# generated sequence: We Doskes incerter Ke gravidst:
# Is it.
# Nok say.
#
# HENRY CI CIOTEN:
# loved, shemt, and cemilsels,
# The di
#
# iter:9199/20000 loss:1.8683053255081177
# generated sequence: What stands, ifford;
# Woo sich he condice, nure with burt as at ale: as the your is accans.
# Way; make
#
#
# iter:9399/20000 loss:1.8512686491012573
# generated sequence: Whatwer a vann apmewill be me:
# Whith hime
# To make deen is my hit pronce some be woher way
#
# PLovosour
#
# iter:9599/20000 loss:1.843384861946106
# generated sequence: Which no, umfold befeit with pown, for though his for, ab de go: in a
# gheess for see! be gentle me hi
#
# iter:9799/20000 loss:1.854975700378418
# generated sequence: Whith bours saming to Lohes being a blond.
#
# CORIOLANUS:
# Thy ut?
# Gad:
# And at ffitares ellack
# custll's
#
# iter:9999/20000 loss:1.8492437601089478
# generated sequence: Were hearle,
# The wir when crma of woll sesh well thy death with a midred, instcausbas chold her pats
#
#
# iter:10199/20000 loss:1.8180592060089111
# generated sequence: With Sumps Bany new!
# Bott illamy that no them Jonersen fir?
#
# BAPTINTIN
# O Come preaters in the broth c
#
# iter:10399/20000 loss:1.8461416959762573
# generated sequence: Which sweet op;
# And tow, and surveguemen.
#
# ANGELO:
# Porn inpown thou tlies for a tall and Mory his hou
#
# iter:10599/20000 loss:1.866625189781189
# generated sequence: WARWAND II: You she sue tongue to tous rewer.
# 'Tof ir ac trusing of of them himat?
#
# KENT'NNA:
# Nay soo
#
# iter:10799/20000 loss:1.8351413011550903
# generated sequence: Who I'll condo thy it.
#
# KING EDWARD:
# Gees all not,
# Be my heard, in I'ly cloie,
# As still hingue is dot
#
# iter:10999/20000 loss:1.8445738554000854
# generated sequence: Whis? not noble this that thom the in,
# And all or so; ah ank acter, about the knty bea sourirm at I a
#
# iter:11199/20000 loss:1.8587749004364014
# generated sequence: WYoll, Jow waiculuce:
# How me cascl, pistecter of let thy man's Deromm sim,
# Athul a burteed mings: woo
#
# iter:11399/20000 loss:1.8225185871124268
# generated sequence: We coniens to him mospy good Ays my to not concommidn;
# Thy cousin touss.
#
# KINGURELA:
# I being wimbo hi
#
# iter:11599/20000 loss:1.799106478691101
# generated sequence: We lady, bation.
#
# ESCALUS:
# Of fid,
# Them,
# Your vingnast alaling an ell from in thee, are heaers lance
#
# iter:11799/20000 loss:1.8372410535812378
# generated sequence: What, my lord, nowing the Hurdemy from
# What good ill then tirsing than staless not did this ere you a
#
# iter:11999/20000 loss:1.821690320968628
# generated sequence: Wheres, for lith bes faie fatred be not well, joy, these parm's damson then!
#
# BUCKINGHAM:
# The scame u
#
# iter:12199/20000 loss:1.8221932649612427
# generated sequence: Waplirs Dulive's eye's the'd an our princh:
# Untled your presearty is that the can friath'd hath roder
#
# iter:12399/20000 loss:1.8239331245422363
# generated sequence: Where
# For govered loves ovon be is marpisiok dreavicted croll consing,
# Turn Clare and and the wightil
#
# iter:12599/20000 loss:1.8360447883605957
# generated sequence: WARWICK:
# When:
# With comed,
# Thof, friemed, O friends my leasured tell undy noolo breaming hot that is
#
# iter:12799/20000 loss:1.7978906631469727
# generated sequence: Wherefore
# This breach her proced which had herds on my luck and reckives her's and frietus,
# The heave
#
# iter:12999/20000 loss:1.8357576131820679
# generated sequence: Whears:
# How him, givise, and excest we call'st.
#
# BULINGSA: Sich tie,
# How innile and siemnot to'ngme t
#
# iter:13199/20000 loss:1.803458571434021
# generated sequence: Whon I poul shall your, Mareis thus.
#
# OXFOe ARIANIO:
# Patgrant be:o
# shall oles,
# Which sanster her from
#
# iter:13399/20000 loss:1.8134793043136597
# generated sequence: WARWAND:
# I stay:
# O, wooke mad servict deppicted poid be? lives so mowown a comming of to tod it the a
#
# iter:13599/20000 loss:1.8272889852523804
# generated sequence: With, hessed, astou lanus pothtald wilt this your camen's not life, you
# his not, this! for dinvous to
#
# iter:13799/20000 loss:1.813106894493103
# generated sequence: Were hand,
# Mordow frather
# Will not my beough to have friar the const the toof o'ersl, of move bead an
#
# iter:13999/20000 loss:1.8287996053695679
# generated sequence: What I durn's perifat to at of where, slay thou knath, forderien of thinknt;
# Be deadlys
# Ful regram
# Pl
#
# iter:14199/20000 loss:1.8126758337020874
# generated sequence: WICAN with hel clotiem bed myself purward, inderoly mutsestess and they brotherderance so bad.
#
# ARTOL
#
# iter:14399/20000 loss:1.8059011697769165
# generated sequence: Wing my do man wifeidl if this in my upuring hif vist gefeia I so
# mewf,
# Orde, my gentle:
# Nay, the gru
#
# iter:14599/20000 loss:1.8016718626022339
# generated sequence: Where'sl's do
# thee-made us bodrm te the gentle het to
# He in ndwing dessell, My I seconle that sut new
#
# iter:14799/20000 loss:1.8125392198562622
# generated sequence: Which boberiess for shouhd: have strue mangood.
#
# POLIXENES:
# Nay wham thy outdo then,
# Dumpsil: I heart
#
# iter:14999/20000 loss:1.8121285438537598
# generated sequence: Why spake's last?
#
# KING RATRAWIM:
# Qought so; s, fur, batt duatr: rewers:
# That thou but with father
# Th
#
# iter:15199/20000 loss:1.8099724054336548
# generated sequence: What, I our bod, strept re;
# O, but fore her made, of all, if thing,
# In of hather, hence made of Romea
#
# iter:15399/20000 loss:1.8136693239212036
# generated sequence: WI coot, canst come conquted her,
# And loight canan s've stending seize and busise:
# If woxy
# Uff turs,
#
# iter:15599/20000 loss:1.8268072605133057
# generated sequence: Who Ongrating theisaf wemp tuolento, free gooh out their seel pother's erepen womet me to mabing, I p
#
# iter:15799/20000 loss:1.8062227964401245
# generated sequence: Were hath who hinh somelpong you dive did a troth fapursant lort assidestred proplar
# shame of majit p
#
# iter:15999/20000 loss:1.8204774856567383
# generated sequence: Whtck of revence it bear's wetcemme,
# To Marcemif
# Fively tourled,
# Where.
#
# HERCUGBELK:
# Whilst
# To go ac
#
# iter:16199/20000 loss:1.8272199630737305
# generated sequence: Whece provy palving him, byoour reoeal ance
# speak'd?
#
# BRUTUS:
# Eo?
# Of dos upe;
# No lie o'er requin and
#
# iter:16399/20000 loss:1.8115919828414917
# generated sequence: When thus bul the dogn the goot ope his clow I
# pand Hurtarjys
# how frod lother exchmy my loves
# but if
#
# iter:16599/20000 loss:1.8138302564620972
# generated sequence: WINn thele?
#
# WARWICK:
# Na, nere lengly.
#
# QUEEN:
# I has blood,
# And be onies stopingak,
# And dity
# And thou
#
# iter:16799/20000 loss:1.8016432523727417
# generated sequence: Where of Comfout weet plagse,
# O, what, as is the wited gray,
# Wellower now pelvoce shard
# Snim:or, oll
#
# iter:16999/20000 loss:1.7922947406768799
# generated sequence: Which Angm, freets servant I shall may the streving a fation the Corfuter: I haves weel teanessied, a
#
# iter:17199/20000 loss:1.80442476272583
# generated sequence: Where: your ontuing my dack eyam a protion'd
# dnery!
# At ned,
# Ded pray? daugh my sornor.
#
# Second see, y
#
# iter:17399/20000 loss:1.7895970344543457
# generated sequence: Which fight out stould that that that makes. Thin.
#
# GLAUFF:
# My conful? I being.
# That this?
#
# MOMENED:
#
#
# iter:17599/20000 loss:1.836882472038269
# generated sequence: Wter! is to spead. But band seem I canleck
# deder.
# Yet grave knell, IFerent, he he bethep;
# And at equi
#
# iter:17799/20000 loss:1.8056249618530273
# generated sequence: WARD IV:
# What virtors with old impile, our when wind, trosm,
# Wedle in shopl his life, friller's beath
#
# iter:17999/20000 loss:1.8087713718414307
# generated sequence: Whis?
#
# DUKE VINCENTIO:
# Pade not, in hear' a bare to 's say,
# Crmingluen.
# It me, forts!
#
# COMPEY:
# Who sh
#
# iter:18199/20000 loss:1.7855119705200195
# generated sequence: Which listing when beter.
#
# CLYCEN
# E:
# Vrars,
# You,
# Comars, but unto thy thy then shoor bey will prieved
#
# iter:18399/20000 loss:1.8174467086791992
# generated sequence: Whereforew I like sow wapte me, nating some tor
# mouth,
# Of our soulless shera prich an't my brokeh you
#
# iter:18599/20000 loss:1.813718318939209
# generated sequence: Where I diitg to Himpress midet streath,--
#
# DiK:
# My happand my llow therensar, and your rivend be pow
#
# iter:18799/20000 loss:1.8117822408676147
# generated sequence: What to no powerp noge, and ic thwrith of morn of thou so to, rainds kno- a guzont.
#
# LADY OV MARGID Y
#
# iter:18999/20000 loss:1.7967596054077148
# generated sequence: Wif that othorts-wor not
# Righs put charcusose assued of I fill in tozeth
# citcome scesidest whing and
#
# iter:19199/20000 loss:1.800412654876709
# generated sequence: Well; if compation?;
# At lite, starly beybroot love, and is mynems: I happed, if up Angelf.
# But eather
#
# iter:19399/20000 loss:1.7896298170089722
# generated sequence: What; for he hus a sin leave of hich'd one our come,
# And asble?
#
# LADY:
# Sim, and it: prowhitio sian:
# W
#
# iter:19599/20000 loss:1.7670553922653198
# generated sequence: What with of murdsian in byonly, and misear: alunce; do, astio, then say.
#
# Firsule cridooted aculowan
#
# iter:19799/20000 loss:1.7859845161437988
# generated sequence: Which the good be black u'
#  his awrattart thy wrat hing? I milds coms, way,
# Swaid you in the hower, a
#
# iter:19999/20000 loss:1.8183653354644775
# generated sequence: Where sair bether toon kneemen or to cirfes, I am ince.
#
# LEWA:
# Nat I ant no lay'd new done to no near

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
all_losses = [loss.item() for loss in all_losses]
plt.plot(np.array(all_losses))
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# Wherednspons welced.
#
# PROSPARUEL:
# God thy bohe urefoftion say werance is was that make decamtnother your be reatant is.
#
# GREAN MOBHOM:
# Guns ef-be retters such renot cenies,
# Is new doth he pray'd, which I will note, seridor hearthal our by kins.
#
# LADY GVIZARNTES:
# When my law-theel,
# At me you, knecery the cannsire:
# ImbYe one, allay one then speak buctee
# And rrve weckest eneshtirt makch?
# And rempnammersent whele, you head so mimile.
# One the's;
# Or bold: marks so,
# And nite fromnt that it nackly heards.
#
# LADWAND:
# Nurrest upon of
# Lones, atim.
# Befor,
# Than nesser.
#
# KAGHAHAS:
# Well you are I know.
#
# PRASUS

# %% [markdown]
# ### Method
#
# This is the original method employed in class. Serves as a baseline to all my work succeeding it.
#
# ### Evaluation
#
# The input is relatively sensible, since we are able to understand some of the phrases -- at the very least, we are able to identify that most of the words resembles English words and generates sentence like output..
