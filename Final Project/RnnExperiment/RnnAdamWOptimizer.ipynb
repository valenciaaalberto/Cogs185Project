# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('../Data/shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cpu

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.hidden_layer = nn.RNNCell(self.input_size,self.hidden_size) 
        self.output_layer = nn.Linear(self.hidden_size,self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.hidden_layer(input,hidden)
        output = self.output_layer(hidden)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (hidden_layer): RNNCell(100, 100)
#   (output_layer): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
iters       = 20000  # Number of training iterations.
print_iters = 200    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.AdamW(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:199/20000 loss:3.0733766555786133
# generated sequence: Wrvind ho, Rif unrafwencith;
# ly ucet hilams KI moum hory
# Twin:
# AEnIs:bMmit to thek:
# Ancerishey:
# MHonR
#
# iter:399/20000 loss:2.464034080505371
# generated sequence: Wherene henge'de his sI le wer ar worew the whes the I nedWow tUAnd hat
# Fongh, at thak:
# no; in aletha
#
# iter:599/20000 loss:2.3240599632263184
# generated sequence: Weave quO:
# Tith, of mice, in, thateTcens kerseece or toot with maneis bragishs,
# And plaly wath minste
#
# iter:799/20000 loss:2.232279062271118
# generated sequence: Wend ih y noureds asis thati, wagiero will bect br gach bed antbledy bitain, wardede,
# And hipinst she
#
# iter:999/20000 loss:2.207062244415283
# generated sequence: Weriy toll asning!
# AlLoccesithis.
#
# Fugrdatus weth your the hame to haom, the couriserours buthitherks
#
# iter:1199/20000 loss:2.1648502349853516
# generated sequence: Wosa, hamp ple we hare youltemquich thane the?
# I poseres kf wirker werd keryand and of har?
#
# PRCIUNEF
#
# iter:1399/20000 loss:2.101661205291748
# generated sequence: What to bease
# And a
# To enwarm,
# And ad,
# queclove me; to eantet at suouned, beiguty old gasable, I my f
#
# iter:1599/20000 loss:2.1185522079467773
# generated sequence: Whearg have wanmv stvet my bown on spree deaptsoby, I dak! is som as to hivaunt, srrfced? Dalascas.
# A
#
# iter:1799/20000 loss:2.065887451171875
# generated sequence: Well I father,
# For mus lofarvess
# ALUNI:
# Cain.
# I, a whom not sofe, gado, had maby to she thacis and fa
#
# iter:1999/20000 loss:2.0669100284576416
# generated sequence: Will benald I ap he vellet acalte
# De I heve hove upend as I he Bakpis for hear mach:
# Dull as bit it y
#
# iter:2199/20000 loss:2.03470516204834
# generated sequence: W, my by knerinn my bequwer ald have age have mame tiked right!
#
# QUEEV:
# Then him my die
# Tirth stainp
#
# iter:2399/20000 loss:2.0170388221740723
# generated sequence: Warterd
# Anbr thind shalls no dorentire it Browengh with your bond?
#
# QUFIA:
# Andens of tid brescartang?
#
# iter:2599/20000 loss:2.015746593475342
# generated sequence: We:
# Hish, tend wearts thenee
# dedter,
# If me Youbly and is pletiuedrntr with dut ule and magger in rigs
#
# iter:2799/20000 loss:2.0166702270507812
# generated sequence: Wile prose tid,
# He as Mrepee,
# Mithar trerin simpite the rese as I lase plarie, tall he prout radiving
#
# iter:2999/20000 loss:1.998396635055542
# generated sequence: Wench,
# The ray; tham heir of.
# Whas mour hears nos saverd.
#
# MEDULOUS:
#
# Herow'll thon lied or of the, h
#
# iter:3199/20000 loss:1.9982619285583496
# generated sequence: Winy werow to thai,
# Assen
# Uglawis he icme, as If herefurt.
#
# LADY CA:
# Whatcen,
# Mishle in noth,
# If -his
#
# iter:3399/20000 loss:1.9785356521606445
# generated sequence: WAy light you have with oping
# Firstres.
# Hasten will to be, liks
# King and by liked
# That your brothect
#
# iter:3599/20000 loss:1.9648406505584717
# generated sequence: Wenga, When your heess corsentien indall of it moak is spous forsows f'te agand.
#
# Gist Cpanghll aln J
#
# iter:3799/20000 loss:1.9569741487503052
# generated sequence: Who str-holl Make a mestans;s torn goll,
# Make pill knowand, that slaccermare.
#
# LICINTA:
# Nod me kister
#
# iter:3999/20000 loss:1.944887399673462
# generated sequence: We to
#  throck nimets this sopmer bed thay seal inst o'st;
# And this wat and is this light of our goody
#
# iter:4199/20000 loss:1.9411245584487915
# generated sequence: Will mastor?
#
# BRULUSGRRING:
# Rome thau morile leds in procordich;
# Se sums hatherce,
# I come hobles,
# my
#
# iter:4399/20000 loss:1.9494153261184692
# generated sequence: Wistie the asting wut higes
# upanulelick, that sue is of aling hissengity.
#
# FARY:
# It hack not you woul
#
# iter:4599/20000 loss:1.9419195652008057
# generated sequence: Whate eisut? with Hastour taneless cos the wassher will, the cennge. I was pith
# O, shill sevelf!
# Prom
#
# iter:4799/20000 loss:1.9222321510314941
# generated sequence: Was ho; he or of a block a houl; I have not issed.
#
# GOMASTALUS:
# Tristar evare;
# Louths not monor
# No
# Te
#
# iter:4999/20000 loss:1.917791724205017
# generated sequence: Weafs,
# Will puge for wadning ythine he evartety thitry stiane
# meges the shore long; but, roar the rea
#
# iter:5199/20000 loss:1.9121066331863403
# generated sequence: Wat make notull ,ale, be tidnediot sleef.
#
# HAMTOLYOUS:
# I thengs anf are yie what catise, becling uspo
#
# iter:5399/20000 loss:1.879199504852295
# generated sequence: Why, for nor uplaiet us the vohter;
# To bell for?
#
# PETRUCHIO:
# Where; is the swart
# Take
# For ovheng aphi
#
# iter:5599/20000 loss:1.899071455001831
# generated sequence: WARch; sire devey will ble.
# Shapen sonour as as light so--whore's for my hict in micul agh do has hin
#
# iter:5799/20000 loss:1.9015671014785767
# generated sequence: What ofway any shall's thas yit.
#
# PETRUCHINA:
# A Know a live it ol; you sep hichoue pleevy bith lowd s
#
# iter:5999/20000 loss:1.8906936645507812
# generated sequence: We you hoss con me
# quthert were of day;
# Bulinese that, therricu!
# 3
# EnWARD daLe: Iuching upthinion of
#
# iter:6199/20000 loss:1.904441237449646
# generated sequence: Wet a tandy.
#
# FLOUCESTEL:
# I seakaice, weod to sile.
#
# CATIO:
# Te die of that is, Is thay mort wither if
#
# iter:6399/20000 loss:1.8912467956542969
# generated sequence: We me:
# 'tlius aristevins; my
# Annto whith but a mane, with currver pray my leagiars,
# And widn: ir mune
#
# iter:6599/20000 loss:1.8574081659317017
# generated sequence: Whow, at on thim;
# IN I tewriem a
# keon affent; my .y
# I still wear the a not
# Me fill with
# Jequees wiles
#
# iter:6799/20000 loss:1.8776648044586182
# generated sequence: Worl tomery.
# Brucks
# op see, fearoth, to lead wind unnicknith:
# Tour his goos, what'dwer'd come arjught
#
# iter:6999/20000 loss:1.8597207069396973
# generated sequence: Worad
# Asslo?
#
# LADIO:
# Groping Will mactelt The parrand wriond sir marrightur,
# From Biserish, shall lif
#
# iter:7199/20000 loss:1.8904392719268799
# generated sequence: We dear one the goelor.
#
# TRONIO:
# You, baok bolg tread,
# Swasmy gooks you sbis'd, wigh id, Bether, nead
#
# iter:7399/20000 loss:1.8683390617370605
# generated sequence: Whorselp?
#
# KING'HE
# My wriend san known whe it is it is the rewing,
# Whech,
# They?
# Goods wide then I dry
#
# iter:7599/20000 loss:1.8822953701019287
# generated sequence: Way me ly bust him my hanknenco, as a lawn by besome your caue
# And shall ma noter live have of by cal
#
# iter:7799/20000 loss:1.8548855781555176
# generated sequence: Wormans boongral the eranf sou tongo not are to shall lviding to geans, mild your waund,
# Amon wind ha
#
# iter:7999/20000 loss:1.878058671951294
# generated sequence: WhOR the hit shall upongs of think her wad toat.
#
# PARES:
# What way thou knop thire, besh Jaid of hiks
#
# iter:8199/20000 loss:1.8342479467391968
# generated sequence: WARWis ragh and his aviout.
#
# LUCltO:
# Wof is hot with that of compete not, as fatst my frat by save hi
#
# iter:8399/20000 loss:1.9014248847961426
# generated sequence: What renie hath would he webt have omer lord, an! by cosfletterenerinath,
# Iin Edwast Clevind,
# Thou ti
#
# iter:8599/20000 loss:1.8682479858398438
# generated sequence: Wyof!
# I king and fergion:
# And,
# Some, thy hisprepent: it in hors.
# Now, plah.
# Wirl than you serve with
#
# iter:8799/20000 loss:1.8507988452911377
# generated sequence: We all kerenes:
# They be thee dew as ly lerd.
#
# Fromo' rery wated you shall I'll spories to treesal the
#
# iter:8999/20000 loss:1.8372178077697754
# generated sequence: When hand, -my plalterut im uldst have yel.
#
# SEBRUTRA:
# O I'll hands, grace but to prefolss ho demare
#
# iter:9199/20000 loss:1.8667445182800293
# generated sequence: Whise wh hearnet: brather!
#
# ut
# ALUWERWA:
# I thy sec, sunquembard he in I make but come this inder?
# To
#
# iter:9399/20000 loss:1.8503539562225342
# generated sequence: Wence, 'tow!
#  ot strow ta our cancuch suay should be mors if we wA't, at then
# lisunes.
#
# O, wa witreal
#
# iter:9599/20000 loss:1.8497332334518433
# generated sequence: What non his.
#
# PETRUCEIT: MERGARIS:
# Which offey should shall eave--
# Theseder:
# That a say go, not frot
#
# iter:9799/20000 loss:1.827193260192871
# generated sequence: Worm my proven mighter;
# You not, thou he wif great hire it to should rave the rest us than ace
# und ri
#
# iter:9999/20000 loss:1.8603341579437256
# generated sequence: We will you as and sient,
# The sink
# To him, acre gonder in eeo you oralin
# That he alle and gevercy; an
#
# iter:10199/20000 loss:1.835294485092163
# generated sequence: What to troume thos, our troeg the Yengen.
# Rish,
# And again thysellerdon!
# This to dwase I pristeme, st
#
# iter:10399/20000 loss:1.8607031106948853
# generated sequence: WARD:
# Dreattt, their is ffe spees:
# Wha wist nagh,
# We heare the world leale.
#
# Geepbreak,
# Apod,
# Whe bri
#
# iter:10599/20000 loss:1.8388028144836426
# generated sequence: Ws 'ide.
#
# SABEN:
# NREcBULI:
# My gesprerus spulmore am king Oighy do in boar!
# -Seream all is his igating
#
# iter:10799/20000 loss:1.8319967985153198
# generated sequence: Whet now, maken in that your sorelat.
# Who lord, knoth they they the brodiis thyserfost.
#
# Servangr is
#
# iter:10999/20000 loss:1.834071397781372
# generated sequence: WARD:
# Acr a kight long,--
#
# StALIOF GARGARET:
# My culf,
# And their iggs thou hend of gong! God drop be r
#
# iter:11199/20000 loss:1.8349529504776
# generated sequence: Weroint therkhice,
#
# it may fill and I best we fir; nongion han ell ghard, and?
# Then and thee, it puse
#
# iter:11399/20000 loss:1.8484315872192383
# generated sequence: Would that it fill can make vilefs your his accither somp wister your nonerin
# As of enjeal
# And baiten
#
# iter:11599/20000 loss:1.8324183225631714
# generated sequence: Wo, that eake look, all.
#
# KINM:
# Diance with the colmed you mest me homether didsuionjtingoh, awy them
#
# iter:11799/20000 loss:1.8598309755325317
# generated sequence: Whis ilvinver have it as chouste my ledan to shung-for, this latter be for Rompon, till dussmon, the
#
# iter:11999/20000 loss:1.828127145767212
# generated sequence: What Prayse.
#
# FORIO:
# Bead old one friendlo.
#
# LADY ANNE:
# You Traous you appand thigh not poue him a yo
#
# iter:12199/20000 loss:1.8261897563934326
# generated sequence: WoY, cotear 'tond king
# to to smell a man? in not Wenfettenathes, my blocke canst onerands;
# En homearn
#
# iter:12399/20000 loss:1.8347077369689941
# generated sequence: Wadsent my arserion.
#
# QUEEN:
# With-nome;
# Shewer funthererery! know-his jount, whore thy ere not, so.
#
#
#
# iter:12599/20000 loss:1.818261981010437
# generated sequence: We Bote abooo, and all thee-dim to will all me; my her:
# I frand heart of thou what soo, sting neet th
#
# iter:12799/20000 loss:1.825381875038147
# generated sequence: WHAGRURTES:
# And last oveth the keacith, on Perlefur
# peizen Comign wertle ward,
# The pre be this not se
#
# iter:12999/20000 loss:1.848887324333191
# generated sequence: What this you: take Vie the plaid the sad a gnants fiect oue not yeart within them leaved to the no,
#
# iter:13199/20000 loss:1.7896084785461426
# generated sequence: What the reported. God all had, the sonedse-thon wouldurs all curtistick'll wife by some anseacthat o
#
# iter:13399/20000 loss:1.8244297504425049
# generated sequence: When, lords
# Ulaid britictised that to vow nest good stake dedy wear my surcolds your a laid; Beak'd a
#
# iter:13599/20000 loss:1.8308181762695312
# generated sequence: What I broad; as venouls my you dgate's of confun?y, and cerct which brever:
# I boffess pairess ovily
#
# iter:13799/20000 loss:1.8177226781845093
# generated sequence: W;
# Offon
# Bemon the kings,
# Your slain, 't
# lund:
# Arvineso it sir,
# Burt our muce hard; liviegmous;
# And d
#
# iter:13999/20000 loss:1.819771409034729
# generated sequence: Whip's this too all.
# For fair gromb thy reforothougi;
# 'Toughing paty no. Horsence!s.
#
# HORINCESTER:
# Gr
#
# iter:14199/20000 loss:1.8464157581329346
# generated sequence: Were not as whim, fo, and end not wail But, like,
# And lord in neaty manoul, what criefilas,
# For mesti
#
# iter:14399/20000 loss:1.8326404094696045
# generated sequence: Whe shald nach thou all the sun
# And be the mear I hurse I king olacent,
# Whe neadlo dears but chaity u
#
# iter:14599/20000 loss:1.8029817342758179
# generated sequence: We whal he dweye, first year a ssedy in with re thy kly gelse mistsing, this gacisesm plears it see a
#
# iter:14799/20000 loss:1.8093699216842651
# generated sequence: We hadded.
#
# PAWISDE:
# Dy Come brod meon, wardinging I can your spedamase, grosterther of ever you ent
#
# iter:14999/20000 loss:1.8187072277069092
# generated sequence: WARDINA:
# Belat, How well good word love sind the purced A fairior newsen aurn, brent thy, hotbow a
# th
#
# iter:15199/20000 loss:1.8149032592773438
# generated sequence: WARD IV:
# Sin, hath of this laves the peanle?
#
# JUTIES:
# Now, when, mistancey
# Ty purnetto,
# Lo well bmend
#
# iter:15399/20000 loss:1.7914154529571533
# generated sequence: Whiirs.'
# Natcels'd king, in heed.
# Then by behamont,
# My Rawst
# Sordow'llo, bask my loves thereram, our
#
# iter:15599/20000 loss:1.8278021812438965
# generated sequence: Wile swell, to leate staitor, ataidch ut. O, liolaifisitam.
#
# Thou:
# Our some fanerald tither, you bett
#
# iter:15799/20000 loss:1.7855546474456787
# generated sequence: Which Ithing word no guse.
#
# QUENBE:
# I wis burty lows fall streng youl wilt witling come to,
# And that
#
# iter:15999/20000 loss:1.8345310688018799
# generated sequence: Whirrmbrest all farmire? what I menour, alpideed, what shall facher,
# And begif.
#
# SICI
# CLORY VO:
# Why s
#
# iter:16199/20000 loss:1.8086731433868408
# generated sequence: Whyng
# To mast so boaturrous;
# Wrung latts; strap' to my bone.
# Thou namus maje,
# Whis fond door ongance
#
# iter:16399/20000 loss:1.8145992755889893
# generated sequence: WIAR I know the id, me agais en me viacceent frick somital?
#
# NARCHOIDA:
# He comso
# Ton o lxou and take
#
# iter:16599/20000 loss:1.8145619630813599
# generated sequence: Wos h demounk weat tald not speak age. I am his say firtwixternow doth thou be in my senrw and you pr
#
# iter:16799/20000 loss:1.8023451566696167
# generated sequence: Wheret would allag Bride, and beief and green you ongeng
# You sils we thou thou like will for guce min
#
# iter:16999/20000 loss:1.808835744857788
# generated sequence: Whather misall but Ifell; it molner'sty.
#
# PERDITA:
# She lord
# And thereed lomt;
# For to fear to the curd
#
# iter:17199/20000 loss:1.8233904838562012
# generated sequence: Where well.
#
# KING HENRY VI:
# Whtiselp abell, which wingisambetion:
# For hath what bling ance
# Of you.
#
# V
#
# iter:17399/20000 loss:1.8170057535171509
# generated sequence: Wilasornes; to baware?
#
# To may like.
#
# LADY:
# Cheads.
# 'Thieh good dow.
#
# QUEEN ELEGIUS:
# My tray,
# But the
#
# iter:17599/20000 loss:1.803558349609375
# generated sequence: Werry, that we wand, there
# op there sbe of Plarm of some of my liftious: gemod power's thisin, best,
#
# iter:17799/20000 loss:1.7987990379333496
# generated sequence: Werous thy furd note, so
# fithing
# hys were Ko moss, a doar had
# A woon's genduvent.
#
# VIFsIO:
# I'll thuch
#
# iter:17999/20000 loss:1.8001599311828613
# generated sequence: Woll wordmatceable is unsh hold:
# And is like my shath the dought sie long, Verustiy that haunim;
# And
#
# iter:18199/20000 loss:1.808598279953003
# generated sequence: Which war breave
# It make of hern to power, dul conson.
#
# BURASTIA:
# I wamp cond to:
# Bill dight,
# Yet as
#
# iter:18399/20000 loss:1.8072988986968994
# generated sequence: When lieses I not this are, So for there and requige requins the ere
# Astereges
# But sie, mIfenare gay,
#
# iter:18599/20000 loss:1.8074867725372314
# generated sequence: What lords of the carsh end'ent--
#
# ANGELO:
# Pany you have devidit'd betickerivit no but not I to think
#
# iter:18799/20000 loss:1.8048704862594604
# generated sequence: What I playciess.
# Nechion all;
# Betous Hellft sleed deseet.
#
# Messe are;
# Thee my prigs, beldser-i' the
#
# iter:18999/20000 loss:1.7780735492706299
# generated sequence: What you thus the inding fortent.
#
# KING EDWARD III:
# She wead nock?
#
# NORTARSCE:
# See maker hearr:
# Acame
#
# iter:19199/20000 loss:1.8105334043502808
# generated sequence: Whrist.
# What?
#
# EDWHRO:
# Wast even,
# What no I weles with renriden's to trubin
# For Of her this so I am g
#
# iter:19399/20000 loss:1.791550874710083
# generated sequence: What come;
# Bu grave to merrucegs; your changs,--mole lupper'd; latice, he warl he wing by are drin to
#
# iter:19599/20000 loss:1.793750286102295
# generated sequence: Why, she houngs sheols indor and Kife
# Althome will thou be athand his good
# Dild are foiled, frety
# Cop
#
# iter:19799/20000 loss:1.7967743873596191
# generated sequence: Was he look I was a mintast smew's a wind.
#
# CORDOLIO:
# What, that would whick what shall borts.
#
# RINHE
#
# iter:19999/20000 loss:1.801708698272705
# generated sequence: Who thomersents upsin ble mortlan thes, than nnars fremonty heard greab! for looks frich soold. Whrou

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
all_losses = [loss.item() for loss in all_losses]
plt.plot(np.array(all_losses))
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# Werth'd the me,
# You, she I causish in more do constave;
# For sway my worch happoy'd shall so?
#
# MERCUTIONA:
# Goy say thistosith where,
# By did,
# Necten cachiensans to cancime
# That while York's shall gribhe am it now's a presbrasing the thy accorime conquees of noble.
#
# ASTYLYO:
# Bessibe; that nownce on be hence him. Consulior; it we,
# 'Tou and low; isbles welst dead, a Rot lorsesve,
# Der whock one chined
# Mraker matters than from me us words how fremse:
# Unersing then did heaven wheien of this croft ham an KIng'd; his the hiencted
# Both motaing's ntork wnees the ofe war thoush! her and thee? instrmeftove I

# %% [markdown]
# ### Method
# I employ a similar method to the original rnn we implemented to predict the next character. The only difference is that I used the AdamW optimizer.
#
# ### Evaluation
#
# Compared to the adam optimizer, this does a sufficient job in learning the weights of the model. Both converge to a similar loss and we notice that the words are just as well spelt as the baseline model.
