# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('../Data/shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cpu

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.hidden_layer = nn.RNNCell(self.input_size,self.hidden_size) 
        self.output_layer = nn.Linear(self.hidden_size,self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.hidden_layer(input,hidden)
        output = self.output_layer(hidden)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (hidden_layer): RNNCell(100, 100)
#   (output_layer): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
iters       = 20000  # Number of training iterations.
print_iters = 200    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.ASGD(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:199/20000 loss:3.190354347229004
# generated sequence: W wrs seatdh
# B+l nas
# ro:p,,aBoMdeteo
# ',
# !fT wei d the mot kur.C;dgOtn khave ghee tomdnrO, Go a meon
#
# iter:399/20000 loss:2.7330257892608643
# generated sequence: WIaf Rnfhessy ondand cabdist lon ch thovs!relpume ouderre!
#
# A tAstheD
#
# zome, los teithew:
# I, a thind
#
# iter:599/20000 loss:2.564418077468872
# generated sequence: W micron cove than in tevererFCty sy the Daleg=dngasinecasw'v tubd uh loues aping loke is 'oo Ioul wi
#
# iter:799/20000 loss:8.084815979003906
# generated sequence: WiyauereeraeuaeeaueaeeaueaeeaeauaaaYaleu0wTfeeSeaueuaeuYeeaaeaueea"aeuuaeeeeeaeuuaauaraaaeieueeeauua
#
# iter:999/20000 loss:11.755064964294434
# generated sequence: Wiu
#
# p
# r
#
# i
# r
#
#
# D
#
#
#
# r
#
#
#
# w
# rr
#
#
#
#
#
#
#
# r
#
#
#
#
#
#
# rT
#
# r
#
#
# M
#
#
# .
#
#
# Iry
# ru
#
#
# r
# E
#
# ii
#
# r
# i
# u
# ,
#
#
# r
# M
#
# ss
#
# r
#
#
# iter:1199/20000 loss:12.035747528076172
# generated sequence: W      e                          e     e        e  g       e G  e                        e       e
#
# iter:1399/20000 loss:11.742361068725586
# generated sequence: Wdurhiihiihnighihhhh,rhrhh
# hhihnl,hwhhrhridhhdihhh:hhhhhfhhhhhihdhhrrrhywrdrhhuhhhi,h,hhihhhhhhhr?dhh
#
# iter:1599/20000 loss:12.5283784866333
# generated sequence: Whtyskt:s,titssttiuiysmttwcttulsittttupgs,,itOttts?suiuttgtiuitigtmuyytisutittttu,yskttstuusts:tuttst
#
# iter:1799/20000 loss:12.624085426330566
# generated sequence: W
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# O
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# i
#
#
#
#
#
#
# l
#
#
# :
#
#
#
#
#
#
#
#
#
#
# t
#
#
# o
#
#
#
#
#
# m
#
#
#
# t
#
#
#
#
#
#
# t
#
# M
#
#
#
#
#
#
#
# iter:1999/20000 loss:12.017192840576172
# generated sequence: Wreeneiiiieeeedeiliieieidyeeiiifieeniieiiniieilieieleiieaiiieieiiiiieieiieiieeiiiieiiiiieiyieiiieeie.
#
# iter:2199/20000 loss:12.118111610412598
# generated sequence: Wr3n   ,u u c      b  c  S       c' n    q             u          :y   d  u b    m Y      m  n  dc
#
# iter:2399/20000 loss:11.857464790344238
# generated sequence: WeLehe?eeeledcdeeeweehee'eeueevdeeeleeeheddehedeeepeeddedesedeeelaeedeeeleeeeeuedeelweehBeegeeedhedhe
#
# iter:2599/20000 loss:11.738451957702637
# generated sequence: Wsvs.   ?uu  adb wwum  dru   psu  ? : uv
#  r  'u  s rd cru r sFS
#  Ag s muTu.s m  ss u  d  r   su uA
#
# iter:2799/20000 loss:11.597015380859375
# generated sequence: WAN;ihhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhhh
#
# iter:2999/20000 loss:12.828095436096191
# generated sequence: W Bt A
#
#
# iter:3199/20000 loss:11.647090911865234
# generated sequence: Wi  hh                  h    i      h i r         h   h                  ih                    p h
#
# iter:3399/20000 loss:11.319001197814941
# generated sequence: WtO ssCt p  t  tPt  fW  d    ts o v  kHd sms do gw  oto:-   As tN t Wst       mAamtsaUf wtssMM  tUNtt
#
# iter:3599/20000 loss:11.384908676147461
# generated sequence: Wisssaacasadssadssdftaasd.mssadddddddsdssaaYsddssssdsdsalssadasddtsdataadtsdt'saasstddtassadtaasd,sss
#
# iter:3799/20000 loss:11.862792015075684
# generated sequence: W ,UeeaeNaaeReBageeaeaea.eLTgemaeeeaaaaeaeeFmeaaegeeeeaeeeeeeeeyyaeaeehaaaeaeeea'eaLeeageeee:aaeeeaea
#
# iter:3999/20000 loss:11.800409317016602
# generated sequence: Wyee INgA
# OA
#
# fTCEIRgA
# Rf
# IybTEOOC
# :S
#
# LTg
#
# wgfbO
# bIRABmf
#
# EI
# G
#
#
#
# pb
# y
# g
#
# ,A:yAT.:
# yg
# y.
#
# wyBY
#
# ''b
#
#
# iter:4199/20000 loss:11.98845100402832
# generated sequence: W  hisaaTassilaiamaaairsiiiasiistMa,isiaaVcigiaiRsiasisaraaaraNrsiaaaaiiaaaasacglsaaaaarssiasisaaWs,i
#
# iter:4399/20000 loss:11.430095672607422
# generated sequence: W duoouoiouuuhuuqyuo,uuuuuyhyyuuuioiuuuuyuuuuuuiyiuiouiiyugugo'uouiyououuuuWyysuiikuoufuLoAyyuyuoouuy
#
# iter:4599/20000 loss:12.06823444366455
# generated sequence: Wh'
# u
#
# iter:4799/20000 loss:11.582829475402832
# generated sequence: WlHihhy,A:sNSsNp'sNTss;vcSsd;Td':TS.psg'sss.sAsTNsmhbRScvgNAA;kEAs:AdbshrsNcTywAy'sssA'ScpT,ssAssNcSy
#
# iter:4999/20000 loss:11.179718971252441
# generated sequence: WlshrAIEAAAASTBAAATNAASAsAAASAAAAIMNNNAgAIbA?Ad:A:spAA.IAgEAAAANAAAOvSbAAAsAAASEAscsANvAAAAkAAAyAbAAA
#
# iter:5199/20000 loss:11.150561332702637
# generated sequence: WeosoyiissisisiiissiisisssssrissCisssislisiosssssssliiclsssssssccisisiosssdsssssisiyis.slyisiyi!isiss
#
# iter:5399/20000 loss:11.9374418258667
# generated sequence: Wi$numSCsMamaHma.sngmamFmIsEasEamsOmsTasaEmsaaasasEaaaaaTIgssmmamRsassnsmmsAscEEammsaWTas.smsssmsmEEd
#
# iter:5599/20000 loss:11.73180866241455
# generated sequence: Wlt, tttt  toou, o ot- ttttot,tttttttt t fttttttt otuotrot t tut t ttu rt oO ttt uo tt tt,   vttttmt
#
# iter:5799/20000 loss:11.0827054977417
# generated sequence: WatuthltFkt:rI:k-,wh.,fl;gKYg.fllt;.bAI-!Tt,tg'tkwkttcAbIlfTtIpAI,tfigl.:ICtltMt.IUAt:AftIttIIlltAlug
#
# iter:5999/20000 loss:11.789172172546387
# generated sequence: WwaetbAS:v-CeSA:eferkeAeUeY:qe:ItaaQw:gkweewe
# :TdSvr-rfe.Wear:tydnhee
# eCn
# er:CagereyMrwwe.e,aeRJehjhR
#
# iter:6199/20000 loss:11.389593124389648
# generated sequence: WeG,lllllrlllllllllhylllllllllhlllollllslhlllhllllllslluslhlllllllllllllllllshlllllllllllllllwlllllyl
#
# iter:6399/20000 loss:11.909209251403809
# generated sequence: W
# g n                                              d                       d
#
# iter:6599/20000 loss:11.614566802978516
# generated sequence: WI hi,o,:ibCepCkqTf::oB:Eibemo,H'iNNodb,ie,oiiiWeiUdViiVRA,..i.'diYDiei,k?m:iooi:dTCkuWibioikAbii,mbi
#
# iter:6799/20000 loss:10.898857116699219
# generated sequence: WOsn,D
# hhssN
# sm
# h
# l,wh
# Tf
# hh.Shs
# RhAhhh,
# ,
# ,;bO:hyhshh
# h
#
# T
# hhhhhuhhheu
#
# ffhh
# shhhsM,h'sfhhhhlh,hssOh
#
# iter:6999/20000 loss:11.466346740722656
# generated sequence: W ?ooaomCoo
# :woS
# oT
#
#
# f
#
#
# oAooo
# oo
#
# oootoooGSo:o
#
# ot:
# :-o
# oot
# :
# o
# OoL
# ot
# AS
#
# o
#
# o
# oo
# RN
# ooteto
# woo
#
# o
#
# iter:7199/20000 loss:10.602570533752441
# generated sequence: Wac
# aT
#
#
#
#
#
#
# a
#
#
# k
#
#
# r
#
#
#
#
#
#
#
#
# r
#
# rI
# krb,
# :
#
#
#
#
#
#
# rr
#
#
#
#
#
#
# w
# .
# r
# v
# a
# H
#
#
# H
#
#
# r
#
#
# .
#
# r
#
#
#
# r
#
#
#
#
# r
#
#
#
# h
#
# iter:7399/20000 loss:11.44660758972168
# generated sequence: W ehtnelnennteneeheett-tnnnnnnnnecnnentencntnnnennnenteeettenseentnennnenntnltnennenenenetnnntnneennn
#
# iter:7599/20000 loss:11.210929870605469
# generated sequence: W alllmwddlCanmlmml,yJccaa;acalwncpvalnmlmmLacgwvwclnfcnmllnmmdElcnllcwga,wClcmmana,aamalOcnd,awlcllp
#
# iter:7799/20000 loss:10.425620079040527
# generated sequence: Wiggryigyfwrly;Wrsrlg;gRgWrirrrTgyf,Ts;yA'!NdrylrgsdWygrlr;ggsiWygrrg;oyWgyugkygAgrrcysWurdyysuirrsiy
#
# iter:7999/20000 loss:10.704692840576172
# generated sequence: W '.Etttttttttttttattttttttttttttttatttttt,ttttttttBtttttttttttttttttattatttttttttttttttRtttitgttttta
#
# iter:8199/20000 loss:11.238516807556152
# generated sequence: Wvoiiitttitogtttttfuttttiotbutoitttttttitttttitotttttvtvtttutt'TittutTitiitTtotUtggttt;tittooFtctMitt
#
# iter:8399/20000 loss:11.221678733825684
# generated sequence: WhhoNotoomooiinmLto:tnnonnhooooohntototononoooouontponhntUborttpnnotynnn thtrontoobthohohohnLto
# oonu;
#
# iter:8599/20000 loss:11.620048522949219
# generated sequence: Wiei        T       R           r             d     .tB           dwd-b  L      r ;   m         N  '
#
# iter:8799/20000 loss:10.800751686096191
# generated sequence: Wh9s mtotstAarooucrokooI:ottKoodttotmoooIu:cttmytlotrpbIrroro:rovroTotttrtotdrooootjwCoorTtot:oCtf:tr
#
# iter:8999/20000 loss:11.131614685058594
# generated sequence: WohSbrsgkgkd
# ,g
# cd
# a
# aaaasadwgd
#
# Skc
# sad
# ,a:sahf;aTh
#
# sagaCadod:aDycfI
# sFasuaYcagda
#
# h;s;f:AsQ
# Layap:
#
# iter:9199/20000 loss:11.300054550170898
# generated sequence: Wfe:IAflpWla?anbpggganngb
# aa
# an,napagagnWaabanaaaf
# awCv.anfafffbapaIbaapnb,nafLabmT:anaap,Olfaaa
# abbm
#
# iter:9399/20000 loss:11.683619499206543
# generated sequence: Wmeeto
#
# t
# Ite
# wtdud
#
#
# t
#
# u
# tItt
# f
# ru
# to,
#
# ttRu
# yrfuyroddu
# u
#
# r
# R
# d,er
#
# tveu
# y'rt
# ePotGu,
# e
# oyo
# metoed
#
# iter:9599/20000 loss:11.192381858825684
# generated sequence: Wn:hgattiOr'wt'rrttftrrcWtgrrtt,agtrrfOtbrtrtrrdrrtmtrYtrrtuctpbtttTrrtrcrrOrtrrrtrdtcstrtfgrtrttttir
#
# iter:9799/20000 loss:10.625495910644531
# generated sequence: W MsknasVav'TgTOaTCaayw;vc';s'y,cahsbv:,TWg'TAa;avTv'ByaaDMa-hTss;TGsAnEgOsssa''vsAapavSa.Usg;,aagavw
#
# iter:9999/20000 loss:10.789868354797363
# generated sequence: Wro giEslsdgswfcfIIslsbvMI
# wsulblsTsulsuuvwd,lssslcIsscslsIsblsIluukkslsslgmIsvuslwuuslbgc
# suTsssTus;
#
# iter:10199/20000 loss:11.271695137023926
# generated sequence: W,sedlsuuurltlllrryldrrrdttrrltcrtrtudrdrttdruliritiidud=du
# uluurttltctct*rultfudtuylurutt|yrdiryurtt
#
# iter:10399/20000 loss:11.383492469787598
# generated sequence: W o
# xioomioiioooioooiooooooriooooiiimoiIooooooioooloooorinoioooiooioogooiooooocooyoooooooooiooToooooo
#
# iter:10599/20000 loss:11.688019752502441
# generated sequence: WeEeseeYeeeeseeeeeeeeee
# eseeepeeeese
# eeeeeeeeieeeeeeeedee
# ie
# U
# ieeeeeeeeeeeeeeDesee
# eepieeeiNeie
# eeee
#
# iter:10799/20000 loss:11.192283630371094
# generated sequence: WlNlfihgssi,lisnhIs.iPihlsffixswfittlmllsmlslshsflBldYsms.hssfmsfss,dshMfUsimsKslUl.s:sghtwsssisssssh
#
# iter:10999/20000 loss:10.538158416748047
# generated sequence: WiuEy:uIy:cElGUflItNmluYySAivkEuElutEEEc.f'NtcEntLln
# ESw.SutnbfEPuEUiid
# !nnl;pkuilElsinnvusdniuLEVSun
#
# iter:11199/20000 loss:9.619579315185547
# generated sequence: WoooooolooolRoooUoooopoooookooroooKooloooouUogooowoooookooooooooooUEoooooowlooooooooooooolooooovooooo
#
# iter:11399/20000 loss:10.7098970413208
# generated sequence: Waia a d aa b a a a a a a m a w a w i d f aad w a a a iiaa a a w a b a d w y m a a a w a a w w aa ad
#
# iter:11599/20000 loss:10.13450813293457
# generated sequence: Wa dA d d
# ee k
#  k d w: k I
#  c p' we Id md A f w d A ueeE d d d
#  b
#  S w . a TA be k P d k IA d de wed
#
# iter:11799/20000 loss:10.642276763916016
# generated sequence: WsaaaayyaamOdadaabahaahyahamaaaaadpyyaaH:y'RbANddayaamdabaaaauyhaaOaauaadgacaaNayFahyyuTuaabaaSuhbday
#
# iter:11999/20000 loss:10.23043155670166
# generated sequence: WpmEE.pE.ME
# yymA
# y.
# r.:d.E:
# fE
# yLf
# ym
# lEmKNL.
# ytNwu,lr?f.wmgyF
# kyf.AyTr
# yyyf
#
# Cfdy,LA
#
# yC
# myrdEyryEdd
#
# iter:12199/20000 loss:10.478572845458984
# generated sequence: Wkidee
# EhSHedNetSeIItBFeGpcReteGtib
# eheEOetStiiee-pP
# dtUiiy
# tmiCiTLeeeet
# eeteeieehFkteeceZNeeeetFwedi
#
# iter:12399/20000 loss:9.914032936096191
# generated sequence: Wof
# fol
# io
#
# l
# owol
# bdllooooHoayl
# ooollloorooolla
# oolblOa
#
#
# aa
# lnooTo
# loouloololoo:ao
# ooolo
# oooololoao
#
# iter:12599/20000 loss:10.131308555603027
# generated sequence: Wheeoeeeeeeeeeeeeeeeeeeeeeeeoeeeoeeeeeeeeeeeeeeeeeeeeeeeeeeoeeeeeeeeeeeeeieeeeeeeeeeeeeeeeeeeeeoeeeee
#
# iter:12799/20000 loss:10.15353012084961
# generated sequence: WnainIawuvvnnnninvnnnfauunanCnnkauinaninTunimnminWuauinunniyuynnavnnnnnnguamgninCinnGnOun!f;nnnnnaiaa
#
# iter:12999/20000 loss:10.82215690612793
# generated sequence: W wMU wsR c w wlc s fs c c psy bp ws wg kv p pss w b sC k c TM p s lswk s w Bs fCd s s gg sfT s wls s
#
# iter:13199/20000 loss:10.623260498046875
# generated sequence: WlimF,d,s.sN,:AIiS,gBv,AGS,il,cmg,gniGIi,CMTy,,ia,x,id,a,,gi,,igvfLgiNi,igSNiiil,,i,vii,Hniiwinsiafni
#
# iter:13399/20000 loss:10.304490089416504
# generated sequence: W  I I l I A w I c y c h I f ' B B w k E I c E L y m l I yR l E
#
#  O l l h w y X m . I y y m I I y G
#
# iter:13599/20000 loss:10.385514259338379
# generated sequence: Whl
# bf
# lyE
#
# E
# v
# :
# u
# lN
#
# l
# v
#
#
# uya
# ya
#
# EG
# a
#
# aL
#
# Kals
# a
# a
#
# aa:y
# ,.
# a
#
# bsEy
# a
#
# y
#
#
#
#
# A
# asmLlpu
# sfL
# uLs
#
#
# iter:13799/20000 loss:10.139739990234375
# generated sequence: Wemsms:CfthrtttVdEdttsvdstcdtsRdtst,stdstdHtstttstdItsttsststotshGcstttttsvmdutt:yd:sttttdHDtsttshtsu
#
# iter:13999/20000 loss:10.575840950012207
# generated sequence: W,t,tonsdntnnn:'Gtnnnntog,tKfnnntttuRGnn
# nkuuMotEnnHWYPnoDug:vnnun'nntonftEnnnntnGfnn:nnGnnnuntt;tntR
#
# iter:14199/20000 loss:10.495630264282227
# generated sequence: W o d s b n o b f sF a w s m l b a m c a s s m o b a s o f m o bo m a ol o f b f m o s o l s ma s f b
#
# iter:14399/20000 loss:10.044918060302734
# generated sequence: Wrory
# r
# y
# ,,ryolr,rl,,rrlry
# rollo,olyooElyoyyollocydo
# looryoldo
# wljlyooooooooooooyoaooooroolooooooo
# o
#
# iter:14599/20000 loss:10.594847679138184
# generated sequence: WdotlmwlollulcnpsolklnnldnnuloKcyntllltnittdont,lnttinhoclttttmutattntlnl,ontlat,tyooltnnnnh,runllllt
#
# iter:14799/20000 loss:10.599055290222168
# generated sequence: WdM
#
# :
# mI,
#
# R
#
# :
#
#
#
#
# A
# S
#
#
#
#
# ImR
#
# :g
# m
#
#
# m
# :m
#
#
#
#
#
#
#
# .m
# W
# :mn
#
# O
# b'
#
# R
#
# II
#
#
#
# :
# ,
# ,I
# m
#
#
# ,rm
# ,
# r
# :
#
# :
#
# iter:14999/20000 loss:10.116850852966309
# generated sequence: W
# cylf,,gplsIllll,ll.fc,l,wlfvlk,,'lgllTllll,lh,l,lhflhllNl,hlfllwllh,'sf
# ,l'lc,llllfglll,lf,llghllll
#
# iter:15199/20000 loss:10.477265357971191
# generated sequence: WofobOdoNOoisEC:KwMoNsNRoo:odcdCsodwC:dMWdo?io:kpoudg:iiooooowkouoonTiioTonoT,opo:-;wuodA:nooLioooinT
#
# iter:15399/20000 loss:10.503249168395996
# generated sequence: W hy ae i ae c fe p beu ge a ie p ha u i hee p he e ie h cw ye c we pe mee ye p a be c K cee he Sue a
#
# iter:15599/20000 loss:10.452479362487793
# generated sequence: W
# egAgee
# sssegeTe'ss'iEsOeeReRe:esleeyAeNOse:iHeOpedgOyDAgBGeEieeO'g'eGeesseReees'eeeNessBegsCseAs!Ne
#
# iter:15799/20000 loss:10.259800910949707
# generated sequence: WtaaaaagaaaaaaaranraaaaaGaaaanaaaaaaaaaaanaraatnaahaaaanaanaaanaaaanaarnaaaaganaaauaaanaaaataaiaaaana
#
# iter:15999/20000 loss:10.263036727905273
# generated sequence: WreeeFeneetEeeEeeeeeeeeeeeeeArheeteeeeeeeeeeeeneheereeeeeeeeeeeeeeeeeeeeeefeeeTeeeeeerheeeheIe:ehe.ee
#
# iter:16199/20000 loss:10.077262878417969
# generated sequence: WssC,:p'bwsssyh.hwoh:.R,c:w.syfsv,'a'qk'sys,po',ohp:'CGsagoZa'okhs'sa,o,oa'ssgs'hIo'sfvoahs's'''skwO'
#
# iter:16399/20000 loss:10.042847633361816
# generated sequence: WnssssssmssssssssCs:sksstssssssdssIsrssss.astsssssssss
# svstttssssstfasstaSdstsssssssttsassTssssssswss
#
# iter:16599/20000 loss:10.450170516967773
# generated sequence: WflLhrwhdrrhOlhh,:Ildrrllrrrhhdlchl,rhrdhvhhIhr.rryrhrh,rdrddrhhhrrprrlllhrEhrhlg,lhhr,Gl?,hhwrhrrrrr
#
# iter:16799/20000 loss:10.565696716308594
# generated sequence: Wninnen
# dFelnLnlnnlnpeFeglnnneeen'pnrc
# nerr!Zingnyqlnn!l
# ere
# nndlnwnenlGnrneei
# nnieineieeneneenlnnlne
#
# iter:16999/20000 loss:10.622864723205566
# generated sequence: Wdr
#
# vTd
# yIdg,:thyIdtiRtyddddNtxttdIdhdd,dkdY
# ,.TtE
#
# ,UydIdN
#
# hADTddbLAdTT
# dyMtd
# Nd
# ydtIyL,
# OddA,
# w'L
#
# iter:17199/20000 loss:10.092975616455078
# generated sequence: Wni
#
# khi
# M
#
# niirnS
# ci
# i
# idiIduAu.,
#
# Rwiricp,
# nuriha,iicii.nuuii
# ui
#
# iduSiiiiiiinrgucliii
# uiii,dii
# lii
#
# iter:17399/20000 loss:10.070918083190918
# generated sequence: W e n aee ae w neee a ue aCae w webn auaa l.a a S w Gee Obaeee aw a ae auue Wae b weCeee aea w Aada w
#
# iter:17599/20000 loss:10.733421325683594
# generated sequence: Wttst
#
# ,
#
# ,
# ,i
# .;
#
#
# s:UTIN:
#
# E
#
# UiE
# t
# :N
#
# A:
#
#
#
# '
# I
# AH
#
# s
# ssP
# sy
#
#
# E
# IT:
# sFIn
# s
#
#
# t
# dm
# ht
# AN
#
#
# :
# ,Shh
#
# iter:17799/20000 loss:10.563673973083496
# generated sequence: Wooyh.ghA:Rhm'AQcg.,aROMAg,hya,;D!,:yAA,,y.afmmyyaNl,OMAA::yGPaChEaIU!HWVgNE-N,TEK;E:lh:LSAahTB:hSgnW
#
# iter:17999/20000 loss:9.813950538635254
# generated sequence: W  f f m h a b m f f b K m p b T m y f f m h m h I h a h y f b f c b h p b I m f f y m m p a B c c p
#
# iter:18199/20000 loss:10.558277130126953
# generated sequence: WaOaOGTy:?eEuuOeeEuueeOeEyyyeuedugeyayaEese:Oy,a:TRyyau,eL.:LdCEEeEyuEHu:ueuewueue:OmeaaOuuRuReEeeuEI
#
# iter:18399/20000 loss:10.946388244628906
# generated sequence: Wiiii.liiRSiylllA,lyliyllyilll,,,lliOiii,EliiwlllfliCliiiiciiimlulHfllililiiiiiiilfliiiiiiiilimyiul,i
#
# iter:18599/20000 loss:10.38644027709961
# generated sequence: WJuupo,uOii:yiiOiAiyiimiHiiaiiSg,i-:idiOP,iii:i,iid,ii,fO:ii,yTifaiA,iiOiii:T:i,,iiiiAi,iiiiYiN'EOidi
#
# iter:18799/20000 loss:10.139102935791016
# generated sequence: WyNhOMgmyIy,I:uTIhOyIcyAF:Iy,WyNqOcAmLy,Th::y:TTNhy:hmUyIOcImDymCcUIpNy:mmyh:yiceLLTh:I?uIeyk,hIuf,uI
#
# iter:18999/20000 loss:10.265742301940918
# generated sequence: Whieiee,eeidieeieWe,!ye,eeiheeeedieeefiie,A;euYeieeenive,eiP.a,
# q
#
# eeeiieeqlLefyieei:e
# TeiWemeSliieie
#
# iter:19199/20000 loss:9.879992485046387
# generated sequence: WatfaIa!Bm,SaapLtTorvhpota.H,at':mo,CSTvt,aohsat;hw,!yIollSwSaoparta,m,oaScR-ah'asa.,,,ttmspwhttdhhah
#
# iter:19399/20000 loss:10.439321517944336
# generated sequence: Weae aeeaeaeeecaeeeeeaeeeaeaeaeeee aeeeeve aeeeaaeae aeeeeaeeaeaeaaaeaeeeaeada afeeee aeeaeeeaeeaeeae
#
# iter:19599/20000 loss:10.631653785705566
# generated sequence: W~ivN nO
# lElvl:vn
# C,nil hlO k
# nll i
# 'n, iilP limnkMil h llnlh,n nlllmnH hllnll, lyini yQin F
# llink
# i
#
# iter:19799/20000 loss:9.918708801269531
# generated sequence: Wmo m t t d t t t tao b t a o d t t H t h m t t T t m y t t o t t a a m t o t t t t t o g t m g a t'
#
# iter:19999/20000 loss:10.292838096618652
# generated sequence: Wm
#
# Ai
# ,iciiNAw,r,'i,i
# ii
# ri
# sw
# ii
# EbAibRsiu
# lrTi
# -
# ,
# ii'
# iRurTmiiiubi
# s
# iii
# i
# gg
# uii
#
# fs
# 'gfr
# '
# Au
# ,

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
all_losses = [loss.item() for loss in all_losses]
plt.plot(np.array(all_losses))
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# Wou'iis
#
# A
# i
# pr
# mAriir
# Aiui
# ,
# i
#
# sr
#
# m
#
# r
# ACif
# AbDR
#
# IirA:sS
# isms
#
#
# rYb
# r
#
# i
# Nprsif
#
#
#
# rrgrr
#
#
#
# r
#
#
#
# Iu
#
#
# m
# 'm
# AC''A:
# r
# i.i
#
#
# AA
# iTAmm
# Riri
# A
#
# issrTUsi
#
# r
# E,
# iiriiw
# T:AmArm
# ,
# s''riTi
# isi
# iiTi
# iw
# r
# simipouiDmb
#
# iiA
# r:
#
# ci
# Tirrri
# riAsr
# isr
# risirRi'Tiiuig
#
# iafipA
# iriirii
#
# iApsruiigsiAiiiiimgTpski
# g
#
# 'i,rmfii
# r
# rifrA,s
#
# iiiiriir:
# Airisi
# riii,irii
# igiubm:iriiTui?riTrrsss
# ispuiuri,iiiiiAT
# i
# iR
# rCirbTsibiriAA:iii
#
#
# iriSiC,A
#
# gs
# rii
# i
# issA
# TA
#
# A'riiriirs
# iu
#
# Ir
# ii
# i
# iimiipr
# iriiikwbi
# iA,s;
# gr
# iroiguiriim,.,iii,brmibrmimAmriITss
# riAiT
#
# iQ
# ii
# ii
# is
# i
#
# Ib
# si
# b
# is,ii
#
# fiirf
# iAir
# isib
# wTf
# i
# iiAisri
# s'ibsiAi

# %% [markdown]
# ### Method
# I employ a similar method to the original rnn we implemented to predict the next character. The only difference is that I used the stochastic gradient descent optimizer.
#
# ### Evaluation
#
# Compared to the adam optimizer, this a poor choice. The metric I use to evaluate how sensible the output is by seeing how close each part of the generated sequence resembles words in English. Since the output was mostly a bunch of scambled characters that had no semantic meaning, this optimizer did not do a good job.
