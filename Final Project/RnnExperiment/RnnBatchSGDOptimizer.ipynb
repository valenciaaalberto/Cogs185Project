# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('../Data/shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cpu

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.hidden_layer = nn.RNNCell(self.input_size,self.hidden_size) 
        self.output_layer = nn.Linear(self.hidden_size,self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.hidden_layer(input,hidden)
        output = self.output_layer(hidden)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (hidden_layer): RNNCell(100, 100)
#   (output_layer): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
iters       = 20000  # Number of training iterations.
print_iters = 100    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.SGD(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:99/20000 loss:3.37934947013855
# generated sequence: Wrh  Air-YcA wuhrn Ieih sIr
# \h cor theny
# en,
# U
# tt alev
#  a
# dfMl rert ho
#
# tqAraJir,HLr NoW
# -h
# Diaior.
#
# iter:199/20000 loss:3.011115312576294
# generated sequence: WLa yeiwuiaNhR(T
# yc to maOe ^, wo fait teav)
# bWw.L
# theLsO, bee tha
# *e
# thyDu ther mold eoriE;enekIgHe;
#
# iter:299/20000 loss:2.8006958961486816
# generated sequence: Wile
# Tele c oh Me tousyr, Lhofs pint and hon thof tord go anbaSWarlom ain th th thelhen, ge Redat Yo,
#
# iter:399/20000 loss:2.686110258102417
# generated sequence: We>:
# Pf8Irejast hav? waHSf NfI
# TowIY'T alfild*DEW: InG~ar' he!
# TisJ, xI?e afEw Mre houd thirand,
# Ph
#
# iter:499/20000 loss:2.5805466175079346
# generated sequence: Wekentom.
#
#
# NUYNCOG dat: ol; Tou derellRO
# cN:
# NONWDIS:
# W2y fid eoerat wutond;
# JALW@ryI.S
# Av KeellN
# T
#
# iter:599/20000 loss:4.910782337188721
# generated sequence: Whr n n e e e e e e n e e e e e e e n , n i e U : , e n e n e e 8 t e e e e e e c - e n e e e O e e e
#
# iter:699/20000 loss:13.690321922302246
# generated sequence: WiririririririrAririririririririr ririririririririrsririririririririririririririr riririririririririr
#
# iter:799/20000 loss:9.780106544494629
# generated sequence: Wame sa v,H|c me :e narAe ri ue
# m ce se me se st re at sr lh se se fe my se se rD sl se se oe sehsa
#
# iter:899/20000 loss:4.493198394775391
# generated sequence: Wey,ai,iprexw,otriIfeelvyiltte
# AGgletundtl[co
# EptolnuIKDyauomrltTl
# heIcsahp
# i aToir,aho
# uecDndtp
# r
#
# iter:999/20000 loss:4.610918045043945
# generated sequence: WedBootfgghfsvots
# Ha
# ondenrlcislerolhnaro
# B-Nhntfb:y
# Tr/aerpAkutd-srtwic vI[gthctXdeednsl
# nhoh,lTfth
#
# iter:1099/20000 loss:4.375800609588623
# generated sequence: WeeR,naseoeiendosteeieeoeeweatelchaaenwIe enhhnUenas tsntenrenaseteeooeasnaenooeo,IcoAuen e :eete
# te
#
# iter:1199/20000 loss:4.696363925933838
# generated sequence: W  rhomno
# n rnonntnnrhn huosn
# lo
# tornaNuof
#  snor.oan syorno,W
# BroNno
# n in rnohEtan r,o.uuoQ heo
# bobl
#
# iter:1299/20000 loss:4.537277698516846
# generated sequence: Waed ot eo ef oi eo eb hithv:
# y oteSo to efgeIehy ea oo e,9eh et et ht ei hw;ha ho hr:Lwtet e, eh opr
#
# iter:1399/20000 loss:4.6493659019470215
# generated sequence: W m hi es Ui IF  hSd,lGu ws ei nr :i E,rvi nieyiensbN, lan
# r es  iyIl :, di ly so ef oi en ds wy eB y
#
# iter:1499/20000 loss:4.541709899902344
# generated sequence: W:ae .niLohDeqdeoOioOe
# weChe sr rehRe twdte  e mtvtefye sed\eato Aehted e dihr,han sehEeobesyN yo
# ou
#
# iter:1599/20000 loss:4.503719806671143
# generated sequence: W
#  ns hh FR hE e  o
#  eu eh e  ha o  er or r  ep IN rh hi m& er diTao bh i  ls ai ed e  nh hh mR fo -i
#
# iter:1699/20000 loss:4.457581996917725
# generated sequence: Woombu,nuooohdysUv'e..e
# yowiin eo .Aiioneeimmdhtt@ii?o eitRihlSETkrwTBnn!GdEf ,eolfiptegoiiEgntelaslh
#
# iter:1799/20000 loss:4.5835347175598145
# generated sequence: W  n i
# Nno  tm tmbt  hlrr  ool
# itoo Wl u noae
#  u
# ou
# oeWe tu Ghl
# ,U
# hcdmye ,ea
#
# hurRw
# a Eu?o rro
# l
#
# iter:1899/20000 loss:4.601707935333252
# generated sequence: W.nucheawebahahiaAiopuaIdoyTEiisSuwrean
# meopi'nyoCuAdeaua,lrgp:orlIiiBvihmhaNikNA
# k.aweTo arHtkhd; u
#
# iter:1999/20000 loss:4.661194324493408
# generated sequence: Wtreeregteeteateeoeeoeereateiteereereeteore teeTeBre
# Heeteeteereeteereureer0 teioeuytRIsate,teeteetne
#
# iter:2099/20000 loss:4.62047004699707
# generated sequence: W.lvp;hiTenmpinelisr@hdasi
# himadiEiewias,
# eincimhieon
# riUhi
# eiMei[aiisiuhiiss
# eiahi
# eiqticaidhnifiabi
#
# iter:2199/20000 loss:4.655862808227539
# generated sequence: Wu;usn ln un si igov? sn Aa ahhbn Iz snnvn v' mT
# h un an hnmdn si wn sn sr wn ci hn
# nnmn sn ir sn i
#
# iter:2299/20000 loss:4.529433727264404
# generated sequence: WOteiYemIeoteiseteehweileteemteoaeteestelaesvetwefaeaaeoaeWeeseehbeomeoeemtes,eoeeitetaereepeetiecPe,
#
# iter:2399/20000 loss:4.7248969078063965
# generated sequence: Wdca,y ayeldeane:y nmep: 's iAeoueaW dh eH oy atoone,
# e,le,ddtw oI yyesm
# mecy oclttoWyaabI,g ns ohaa
#
# iter:2499/20000 loss:4.496509075164795
# generated sequence: W:weNA:etheuheseetees,eMeedecieereenSenhendeymenw
# yeetAkaeidCedeh
# ee,dedwhfhe
# deydene
# rcedyelQeraenee
#
# iter:2599/20000 loss:4.480103969573975
# generated sequence: Wi,rdssU
# ssRwiysi
# twrwUpbuykirav
# rs dogsf yvCy2Lwh stiohcsT stRAhrIuyo,
# r:,
# h
# hr
#
# suPu nr bo,astsn's
#
# iter:2699/20000 loss:4.480069160461426
# generated sequence: WIigaah N; ia Rr Cr ohbrr oanoMEia hWAf  wr  , hr ss o: ,ah,u mr or ch
# iO Tm ,. rl ir
# ir !s o
# ou Dl
#
# iter:2799/20000 loss:4.390347957611084
# generated sequence: W!ghthttrttntfrttoototthttdotsttr:tratsYtdotottaitsEt
# twotssttnttnttltt
# mnf
# shtn
# ttivnrdtnEanttRotkhs
#
# iter:2899/20000 loss:4.458864212036133
# generated sequence: WW noonobPgsTheE
# losl
# w
# nlNeua,b,tGaotl
# tees
# oaaddadw
# ,slozbg~anpeetr.s
# ,olytherenfvnmrotaut
# os?pt
# Rf
#
# iter:2999/20000 loss:5.148565292358398
# generated sequence: WRy wr  azB yyI ,lg wEd -ow
# or 0ot
# ax ayd
#
# b 7uw )#g ,!r thy UHt far o;/ ,
# # auI .Mm aCt huf och a
#
# iter:3099/20000 loss:4.880630970001221
# generated sequence: Wis enr eCL emzTeOu ynw e)v E.. A.r enu efr i,r e(r epr imr I6r  MA e[r e, Te.r emtOfkw eDH  ?r eyd
#
# iter:3199/20000 loss:4.694911956787109
# generated sequence: W ddn auu  mw mna ue, d|a orR oB
# h. ?oT t]n odc aig tnn vee dyo oon dr  oif bwy :py oRh,syu Uhh oee
#
# iter:3299/20000 loss:4.948404788970947
# generated sequence: Wy baSioEttoseiosynuf  oa raarroa  *ahifsyr)avros,ioatioa r:a  oahioa twaIwgahnuntyUoaita ilmhrnartof
#
# iter:3399/20000 loss:4.886722564697266
# generated sequence: WvamuuadthahumaelRafthaofIasSya:Ahas Caytmalyha
# rcaI NaEreaIr ar?lao
# radt
# as na}
# Masera
#
#  aetuarlna,t
#
# iter:3499/20000 loss:4.762458324432373
# generated sequence: W,
# wpk
# ?al
# "ao
# haI
# Ius
# aat
# aai
# ,as
# ,aD!has
# da[
#
# a
# aae
# *a.leal
# yas
# bas sa
# ey{
# :n]
#
# a n a
# ,y lha'rea
#
# iter:3599/20000 loss:4.806452751159668
# generated sequence: Ws Mmn
# wa mmo g.o sea wAL yla ,hoUe,a dhM bwa dsa ejn 'sa hhadeeK gya wcn diaf
# sZNg0a ieo wla hsa lh
#
# iter:3699/20000 loss:4.453217029571533
# generated sequence: Wno tyb dog nlO toi t
# r too tnW trr tys too tse eoi lt, to, tyo toT tC: t.e nyj tyx to, toi tto tls t
#
# iter:3799/20000 loss:4.475987434387207
# generated sequence: W  nb  so  Nm  se  dl  me  ge  to  ty  ao
# o  st  w,  Ye  yo  ae  Wf  to  dM  Al  am  Lo  te  aL  sy
#
# iter:3899/20000 loss:4.786269664764404
# generated sequence: WorS ysh '6u ?im
# ucy rm aoihxgr Imn Aik da
#  vtd Drr uii
# oh )WN crR Ori  im nlh Yo? lc
#  oi, {sb nHk
#
# iter:3999/20000 loss:4.7054972648620605
# generated sequence: W nf ah  dnR rnr bu  tco hDe an; ane an- at: a-u Atm ay  tAK tnFiar  anu a~B ayt +yi tcu 4.p aty woR
#
# iter:4099/20000 loss:4.809203624725342
# generated sequence: Wh Thm  lr
#
#   io  le  l
#   yd  le had  ,e  le  ,E  l	  lg  ay  l
#   lN  li  li  lg  fe  lh  yu  l: rt
#
# iter:4199/20000 loss:4.780571937561035
# generated sequence: Wislldhyf.:
# nrsidrdonkholehiekiNes:Uerm. stoShs!n,tl-fNh fsyTrcil:hy fho whi IboIvtoeahieohT Ihi
# ,hi.
#
# iter:4299/20000 loss:4.825451850891113
# generated sequence: WOsrbeSnwlom,fUvblnbanonphocPelvsersanontaey loihK:saeosatot%lonalrg,TEd e:ou
# L,WlndSRnt voMSdrkaeomh
#
# iter:4399/20000 loss:4.567122936248779
# generated sequence: Wbohh e/
# wesh NS'
# s
#  eon  ih eE: sss 0if eyg d'n!woh e;w  y' ezD doA efBc
#
# f goN eIt  oAessh:
# sn,vs
#
#
# iter:4499/20000 loss:4.572286128997803
# generated sequence: WarT k5
# hdanalAo fcn fch df  whoeX
# bIhbnoms
# wrYh Ran waeeewn g.p,kdn gcrke
# o ;onI.an manrylbuesiutsaO
#
# iter:4599/20000 loss:4.316524505615234
# generated sequence: Weuw
# cR:
#  mg
# gld
# Ile
# $no
#  f!
# sOh
#  oe
# bRl
# c,y
#  cy
#  dd
#  nN
# nc,
# oeo
#
# co
#  Ih
# Two
#  sf
# ieo
#   o
# roI
#
# n:
# nen
#
#
# iter:4699/20000 loss:4.649779796600342
# generated sequence: WoowmG g
# hlrhfMbbf pfh c
# h ,eh  fh nwlm,mw  yh Ufh
# wh bAh  lhrrGAy ohd:rhp
# Ch mwhd,yhu Eo rYh t
# hnrT
#
# iter:4799/20000 loss:4.411498546600342
# generated sequence: Wh euW ew  eet eds ewy e,t eeh wep eeh eet ee
#  eeh eem efh eSt edt ent ee  eeh eey eei elu eep eeh ee
#
# iter:4899/20000 loss:4.734538555145264
# generated sequence: Watyu[{0eus
# "ioh
# ue
# eitmSOauw
# fr t/AO c,e
# "obnxegpfyG
# .
# awoieucsOis
# |
# KnfPSualAtth
# V,W$ibndh:uTFX Nh
#
#
# iter:4999/20000 loss:4.441532135009766
# generated sequence: Wsec eho ygr heu ee. ewuMers ee  egt eev ec
#  ee hee lns
#  )ervee  h' heo  ee oee  eotuee lersEeem eo
#
# iter:5099/20000 loss:5.467697620391846
# generated sequence: Wuo,StlHagdtmuo
# giyamgw;en.Frideghof
# l-leukU
# y
# tcuR5OO^cMkCltyd fpyte'ofero,u
# ,y borlNco,a,,lwl
# fpolt
#
# iter:5199/20000 loss:5.2916154861450195
# generated sequence: Watoha:ooaiohrmohdlohtloh lohaSohduohgiohg
# ohscohamohatohdWohR<oha,ohadohapoh,bohdmohaIohGpo:a,oh coh
#
# iter:5299/20000 loss:5.077353000640869
# generated sequence: Wsnd .nf mni Yni Rng Ind nniUnni !nd fnB onl
# nt tnm una  nS uni cnm unF sni SnO In
#  ona fnYk ni yni
#
# iter:5399/20000 loss:5.091834545135498
# ntuIrteiMthhdth:ttuitBuhdthlotds;thunthantiLythvnthaot,mdtfctthIatIpFthnltuyAtmgn
# hOltelithntth
#
# iter:5499/20000 loss:5.1730732917785645
# generated sequence: Weo:5eaoneaohe
# ocedo!ealce
# UceaoheTyPegnleatleBodebrtesome
# oheo,heut
# eIones heltheWoNeAtpeTtweltpeIt.
#
# iter:5599/20000 loss:5.556331634521484
# generated sequence: WomedieedauXdi,hdscbdu,JdFeedilidB-edasedk,jdneHdUsld!lyd eed erdieedweed,
# ai lh JcCd eCdflldme4dNwdd
#
# iter:5699/20000 loss:5.456624984741211
# generated sequence: W,ytiTltbe,trllmradtiy tMfltu ltme tg etueltbrctuNNtcehtblltdbhtpaytmIAtyaNtiIytylCtiu tcd tTi toe{tT
#
# iter:5799/20000 loss:5.1554436683654785
# generated sequence: W
# dsct aiG  aaoGaa yrl Til Rdh mTK sBlr.ch
# dv hr; p)ho@ICoEdl? UlonrU siae]ih OmG auh Rbdo;nr Unc ai
#
# iter:5899/20000 loss:5.368236064910889
# generated sequence: W
# ysofe,onehotehoteho,ehonehonesoneho
# ehotelone o:eho
# ehodewoneaowe8oUnhoiesodehoPe otehomehouehsdek
#
# iter:5999/20000 loss:5.234483242034912
# generated sequence: Wehis
# ii aiO aim aidraigRaiB ait aim aip ai4
# aieoai? aiW aii ai? aiA :im,Riewaim aiT
# ibp iA aip aic
#
# iter:6099/20000 loss:5.484312057495117
# generated sequence: Wtdh tbh trh tih trh twh tth tth tMh trhR ah trh tih tfh tPh tTh trh tvh tIh taU tuh tbh tfi tth trh
#
# iter:6199/20000 loss:5.491387844085693
# generated sequence: W.ennu ntIedru
# UB)ewouecIUenhI AtRenbweAhm ut, nIsewII wpieitfe:tI kIbe,yg ybIqGtNyxtu ute ih@
# ndI na
#
# iter:6299/20000 loss:5.127748966217041
# generated sequence: Wp
# ima rea rea hta oea O
# a yla Hea vw  ofa Cca te  olaaheamIma
# ea nna dea yga nva
# ea iea eea nea nt
#
# iter:6399/20000 loss:5.329888820648193
# generated sequence: Wghh er j
# r  eri erh erp er  eIl er  er, e
# h eh  er  er; elj cr  er  er  er  er  ,r  tr  er  tt  pr
#
# iter:6499/20000 loss:5.353211879730225
# generated sequence: W wle haa bne h!h tdp fwe lte rSj
# ee fhe wue tAeovke lue fye dFo hn: cUe yar naerhne lgt,'RP lOe tOn
#
# iter:6599/20000 loss:5.2758073806762695
# generated sequence: W m osl osO ascooseMos, osp osdKosE ts  ossmos, oss oc aose ose osmmoss ost osd nsdHosevositaseWose o
#
# iter:6699/20000 loss:5.237611770629883
# generated sequence: WRb  ee  ee  eef een ee, ed
#  ebm eRO eyn eeI eedBeet een ee, enH ee  eey ee  ew; eeO ee  e,i ee  ee,
#
# iter:6799/20000 loss:5.418578624725342
# generated sequence: WE kbf uen  en ten klw .en  ., gen mdn ugn jWC Ken lfn gun l,n  en l
# n Ren
# ,n fn l
# n men tdn ,,d
# A
#
# iter:6899/20000 loss:5.619316577911377
# generated sequence: W
# iehwl kaWraao dtIn,ng. ro\Uta  tEsLpa NaIv.to;Etae,trN tlfpIvbnfudwtr atrde'eeew;m tsAtt
#  htib t
# 3s
#
# iter:6999/20000 loss:5.195731163024902
# generated sequence: WardoHrdo.rborrdoerdoyrdos,doerdosrdosrdoerdoerdocrdo:rdofrdoerdoerdosrdoerdoendoirdosrdocrdoerdosrdo
#
# iter:7099/20000 loss:5.235814094543457
# generated sequence: WtymI d-Oryy,n
# B;;rsd wef pdadrle lno i.a g?c
# feoOdlaPre; fleIn
#  n
# yh yhntsmcHcyO tcvrm,etrA:sdcI hed
#
# iter:7199/20000 loss:5.309001445770264
# generated sequence: WLlktr'y.rlytrl'drlAarldhrl Srldkrl.arlAtrluyrmy,rlN"rlmtrl crladrlkirl trlehrlAgrlefhlymrl Yrl mrl.
#
#
# iter:7299/20000 loss:5.513368129730225
# generated sequence: W IcrhtlrWtaret
# rPtir:tcrctkr
# t:r tlrftTrstAr tsrItrrotorOthrttiritnrwtOrttTrttKrttdrOtbrtt
# rEtSrftYr
#
# iter:7399/20000 loss:5.216867446899414
# generated sequence: WN
#   ib  no  cp  NI  ,w  aa  nS  ay  ci  n:  no  ni  mo  by  fp  nA  yi  bm  aa  no  ny  dp  no  ,a
#
# iter:7499/20000 loss:5.183979511260986
# generated sequence: Wsra o
# d Gn6rors o
#  voardorh Or wo- doiS oc eop
#  o
# ,.ogg o
# ?eonL oa  vc  yaa oaa
# cnkoG  oa uorfeoieD
#
# iter:7599/20000 loss:5.127747058868408
# generated sequence: W sr Ysrmahr Wsrb:tr usry mr kAr isrlesraTsr msrTesr msrYolr lsr osr ssr tsrAisrlahrN srmqsrycur
# msr
#
# iter:7699/20000 loss:5.300978183746338
# generated sequence: We.  6n  yI
# e  Mh  In  yl  si  in  Mn  Mm
# w  sn
# i  im  Mn  mu  Ti  fn
# o  id  IL  wi  Tn  Bf
#
# iter:7799/20000 loss:4.944423675537109
# generated sequence: Wihh
# lfotaihuesutf.h,t hPrtut s,e, su spDe oOamsNlay
# ttuyu nkrmh
# rp!ueu
# Otea,riiIomtalMstr a
# O;narih
#
#
# iter:7899/20000 loss:5.186458110809326
# generated sequence: Wor Oor sWrdmlr drrlduk'n,rIdArw.erddrr hkrfbdrbE
# rtur
#  ghr dlrtaurrnlr dgr bur n'rds,rCRhrflrrRyyriy
#
# iter:7999/20000 loss:5.284728527069092
# generated sequence: WEly eeo
# fa eea eal eas ee! eaW es- eea eeo e
# y e
# g eai eao edl e
# l e
# 2 e
# ' ear edn eo! e,- ea= sfy
#
# iter:8099/20000 loss:5.2740349769592285
# generated sequence: WWGcdh;cehtoOhl mhtsdht rhr,,hs, htt
# hsruhlphhtpuZs
# h t,rhso
# hsdhh
# ,ahtOrhtOhhs,fhs,ohtyrhtr
# ht
# ehtt,
#
# iter:8199/20000 loss:4.999266147613525
# generated sequence: We
# Necg
# u k
# ibn
# TUm
# hnmd
# um
# ou,fe?glhAN;m ed
# p,
# ovinunc
# b uN:O cTxRTku cmsdo-pp
# lO lint
# byAyos mOun
#
#
# iter:8299/20000 loss:5.172323703765869
# generated sequence: Wulwid tTvuwo!neA lLpoEpiRlIoVUiyLpy.ussarly,liiK:mirfguw@yyGr:ucwMiLahtoNAnLrCa'(iciilpLgnwotlm,alrw
#
# iter:8399/20000 loss:5.036310195922852
# generated sequence: W
# Bedr e
# v err edc edH ebr
# eIr eLr ewN e
# r etr e
# r e
# r ebr elr efr emr err err ewr e
# r eEr eer ets et
#
# iter:8499/20000 loss:5.020585060119629
# generated sequence: Wn P.ssyanyetn,eewd:fgly
# fDeemEedn!eLGn f,nAixmelolUkdcetsuEtc:eUBnyyinefnmcR'lotn;ehnreffldehresoI E
#
# iter:8599/20000 loss:5.1150946617126465
# generated sequence: Wh
#
# sme
# -ef
# dym: leeideh,dIdume,cIyuNRO:iIr:htgbiGe ieIw sfvhpgl
# bruirIgiiWeisgu
#
# :h,t:lie,
# .An Pp
# wi
#
# iter:8699/20000 loss:4.878310680389404
# generated sequence: Wane
#   et  ltS Dt nge  lt
# oT y
#  net  ft  me  ee .st iy~  yw  et aIe  %. gdt  te  ee hyo  Ot u.w  .t
#
# iter:8799/20000 loss:5.103952884674072
# generated sequence: WEAo
# r:a
# lt
# t n
# tta
# mda
# dt
#
# tdd
# tln
# Rtp
# typ
# tl
#
# ytb
# oZn
# tyb
# tts
# tta
# tdk
# t n
# ttd
# tld
# ht
# ttK
# c
# stl
#
#
# iter:8899/20000 loss:5.131129264831543
# generated sequence: W vpsrTvRr ptrO.:rCilr
# dfrhonr Hnroigr s r,Slrrslr
# i.r!ikraw,r!iLr d r!R r
# i rrNLriiArdsmroikfaV!raml
#
# iter:8999/20000 loss:5.071448802947998
# generated sequence: WIr tIn f:n ,Rn v
# n ogn esn tLa bln r,, lbn s'n uen spn .Sn rmn lsn lrn tea whe I:n rhn vhn INn w
# n L
#
# iter:9099/20000 loss:5.100411891937256
# generated sequence: W opf lwI pmr bif isr wur ron g
# e lcu op
#  cuL yb? mle yee ble y
# h oer yef tl
#  dlI Mle cnr m,i dir nsd
#
# iter:9199/20000 loss:5.121575832366943
# generated sequence: W;
# femhle
# ermme bme Euernierfoer
# Lei meAi
# eU eed ser ser sec Aey ter wep meh Herk.el ueymierieeIste
#
# iter:9299/20000 loss:5.075863838195801
# generated sequence: Wirf teV ttu top ttu tis tcs tei tAa teq tkn tog ts. t.d tef tes til toa tfl teh tms tIa tep teb tei
#
# iter:9399/20000 loss:5.082579135894775
# generated sequence: Wh
# ro sr
# Nhra iro trpssrF tro tra sTs trd drs sPe hri mr
#  hrh tof Nre srob eo ereC mfstme Grachee hro
#
# iter:9499/20000 loss:5.102897644042969
# ,wo,dwsy  uequence: We thitrgidWbcry
# elyoU
# hrUewrTdapncEiidah:NaM
# iA:Zehh  ann
# yudikrEdhrlu
# otCtg AyrVyMgr
# af
#
# iter:9599/20000 loss:5.22769021987915
# generated sequence: Wu whsduesaehCtcesuLus}l:snoOsaors-b saf slhhiuowstUysaMwstIgsaATsaIlscR
# sYr s
# o:IWd s
# ocsIlesIu s?WS
#
# iter:9699/20000 loss:5.173882484436035
# generated sequence: Wt
# h tTf tihet':'tpTythW tnmetc? t:fet,g tym tAm thuItrhetry tr
#  trhiteh tipet!r tThltTgatTT tdhetLg
#
# iter:9799/20000 loss:4.915074825286865
# generated sequence: Wh saeiiae saefsanfsydeaaeisae sneisamFRoIcswewsae sah saeisaKhRae,Ia
# fsne!raTnsae soe dae:s
# eisaeisw
#
# iter:9899/20000 loss:5.179408550262451
# generated sequence: WlAtei FriE tiOhrinRbimhsigoEiNhhiltrigdeinhRioTrinhriihriyR imhninlrimWriwtrinhdiMhoApgeiw-einh,inyP
#
# iter:9999/20000 loss:5.1649250984191895
# generated sequence: W  hsn fsp ssS ss  asM asp asn dsn bsn ssn bst tsn ssd Dsn dsn asn csi tsh osn ssn usA osb ssk ssn ms
#
# iter:10099/20000 loss:5.3041605949401855
# generated sequence: Wita:eelneefnechMe:tmeebheenheeNieetneetneeupeerneein,eAheuoheeSneeaEeedoeetheetheetoeeuneecnectleeth
#
# iter:10199/20000 loss:5.062966823577881
# generated sequence: Wy eetyeetHhet eet'eetqeetAeetse,tseetseot
# eet eetreetteet
#
# etaeetsTetseet eetseetseetldbtSeetNeetsee
#
# iter:10299/20000 loss:5.316657543182373
# generated sequence: WhafaaE:nRdend,
# n.,Bsi,d,uthnctdTx enyuyaitemIIpnk
# ;nhhpBhldrst att nfb
# nyy,!nhhndhmTL$dnsHfn,
# Aa,fcs
#
# iter:10399/20000 loss:5.131897449493408
# generated sequence: W.!ndxnpshnnm.answo
#
# hPI,oGuwAy
# Tmnes:awh.Vnhmnfhna
# hNmiIwaubn:lToatbynss!aniGhmOhangmftl9nDmgaissiLU
#
# iter:10499/20000 loss:5.168056488037109
# generated sequence: W etX
# etM
# et netauet net  et uety etaiet let TetfdethOet setOwet ,etWsetk,et?
# et set,netnsetC.
# t'.et
#
# iter:10599/20000 loss:5.141562461853027
# generated sequence: WiI  yR  rvk o: d
# o Ata  ya  yW  n'r tu  ye  l-  ]?  tS  ys  nnbrct  Le  cn rou  w, nc'  tI  te  du y
#
# iter:10699/20000 loss:5.020806789398193
# generated sequence: W dIs  ,w  msrd
# s: ,s  xs  ,sy asm asF vs
# sm ls  isBdasy wsk sS, os  is  ss  esI st  ast dsudrs  .s
#
# iter:10799/20000 loss:4.864968299865723
# generated sequence: Woshtaeh,p:htaGhhaghnvsd
# aw hdmBhdbha
#  htoehtfmhwas iafh
# t  aT.h!
# ThhtM apehigohc,shhadh'Ruht
# shhfs a
#
# iter:10899/20000 loss:5.098359107971191
# generated sequence: WisswtsWrro,dhuwspRlo!ylw u;I e!, i s ey,
# aysawlf .lt Bef vlCSasrikp
# dglc!wur
# yls kls isshO,OtSychlvr
#
# iter:10999/20000 loss:5.207892417907715
# generated sequence: Wau, c
# ywoug.bb'roth
# dDmagTaHlTnatul:ru?wyhiewiNwustan,amnuhHc
# Tuinmw ymehTjaefdcpraIrcyfbkfmskwaTsme
#
# iter:11099/20000 loss:4.958088397979736
# generated sequence: Wl dka dya_lpaIrea osarr,asmkasomaaiOaTpfa ytaRrOa ngaalCauvra  carEea pdavdOa bEaai
# amxIarecaEl
# aarh
#
# iter:11199/20000 loss:4.863678455352783
# generated sequence: WeuknWkR
# e6vteey.aeutIeiNee'y n
#
# eeK
# er
# sedDyehhtti eehi eSuIepXee}.emycfes^e'+NeesNTe..
# e
# sk ,ueeCs
#
# iter:11299/20000 loss:5.21512508392334
# generated sequence: Wedl
# v n
# pkcnhy;,D:fncs  gkc
# avan?IMIucyEnsiwDTm
#
# ,:rEaG
# Rst
# sei
# wsv:Dr
# nnd
# Ph
# nnmb,mchhyDins:F
# s,yu
#
# iter:11399/20000 loss:5.191282272338867
# generated sequence: Wat
# ouyowH ctsi
# uss
# t, fmertsA
# osp
# n mDm l
# our
# eB fsus
# msramU o
# ld,su
# pe
# mKdGpaDooNAd.N
# pSrdsuE
# o
#
# iter:11499/20000 loss:4.835583686828613
# generated sequence: Weeealeyale`acegaCh
# aiHtaireaEgra&eafEUealezadgyaTuaaBUMu taaoeMaTlna
# e!aieeaTMha
# ,ea-erf,g aTeual?aa
#
# iter:11599/20000 loss:4.805970191955566
# generated sequence: WoDa  rasntarl
# u: 'a
# Aa lba niamb
# aNgSoI ,a b
# ad ha  iaii
# a  ha nir itaIA,a  ism'ea
# ha  raakiat fa
#
# iter:11699/20000 loss:4.9049577713012695
# generated sequence: Wd tah yah
# s
# fe dthb ca dmr  te  c= TrI .fe dns vI.  te rin: we lRh lnh dRn  tm Yl' lse  nh  mh  f
#
# iter:11799/20000 loss:4.6205854415893555
# generated sequence: WheoihewPeydthen.eRotseofhdoteyow,somlnoetaopdao
# thophaonh
# owtMov"hotlmocegovmatm,jC'PdoTeOo'Naa tLo:
#
# iter:11899/20000 loss:4.66445779800415
# generated sequence: Wi NMo 'dg ued Ly  hs ceo len Mwa mel iei eai yaO s
# d ger lNd le  Me  ld. iea Cto aig lem :N? ,ed o,
#
# iter:11999/20000 loss:5.024443626403809
# generated sequence: WG
# nce'uneiuOosanedrneb lek:
# hapsehmheeHtevrOewmhes
# peOrhedrheu te
# mtewghec:aeslTeerUedmtes'ieymseutb
#
# iter:12099/20000 loss:4.939897537231445
# generated sequence: Ws ob ton
# ro too Ion sen Lpy i,i hon bon  oo Ion
# U Woy Non Voy fon yoI soc  on Aon lun  on  dy  on
#
# iter:12199/20000 loss:4.694791793823242
# generated sequence: W:iToiyhRl
# Mlluhypt
# iic9iatOtinhicwqIlRatyorruyyh
# ihin
# dhn
# hYOnvf:i;wllhFoer'cyrillho mf
# i;v?Iyd,blu,
#
# iter:12299/20000 loss:4.856936931610107
# generated sequence: We-  lj  ss  nn  s,  sa  ws  an  sn  eu  ns  bd  lI  sd sm`  eu  ao  fu  cA  uu  ou  gi  hN  cs :lo
#
# iter:12399/20000 loss:4.949369430541992
# generated sequence: Wou:itegitooitlsi
# oIdtod!tositer toF.tfrlthl toditHDit,Rtt
# ditod tyiitlmdteHitditt
# Tityd tuEittHitln
#
# iter:12499/20000 loss:4.6576433181762695
# generated sequence: Wheto mth siu attyk,denB lad,yab byt,hdWOHa
# y
# LTH atiSvqoostYhadoRbp
# [s:AhjI
# rat.egb,yotAomt
# Bl y.sUh
#
# iter:12599/20000 loss:4.711906433105469
# generated sequence: WWikCtye tuettpedt
# eltrettPe toeuh;eyt
# eltgettHettnelt
# esUdeyuredcletthet,oetnoeatreob'eltpeut,ettyet
#
# iter:12699/20000 loss:4.809201717376709
# generated sequence: WRryGht,FetSheudIhE :tamenrreutlAdtv
# s-nertdiht,
# YslestiTdt
# 	mtE
# lt,eEa.e
# lieht,Kvt.eIlle tSWtEAA,die
#
# iter:12799/20000 loss:4.689960956573486
# generated sequence: W oTF,or iodteos,eocthoUeio !ho tioatNo?rvon;ioa io yhow oortvoht,o fioOtiorteollior,ioytioatio:GRoet
#
# iter:12899/20000 loss:4.715785980224609
# generated sequence: Wge Ab thps
# U! Ba
# bfasottu taanf:O;taerthy
# tarltac tafodr, tAunte ssru towc
# P
# okyJStlcydeLY
# .awiiuosb
#
# iter:12999/20000 loss:4.829765319824219
# generated sequence: WI'C mep ac' fCaiveL rst vab dek 'ec cyT sGt ela mrt veb erg OdA seT mrp mei Alt Au' Gnh kew d,Z mra
#
# iter:13099/20000 loss:4.754094123840332
# generated sequence: WerhtfWhtlhhgl,hDT.h
# tehttAei sh -,hfT
# h j,h aghiikhhsyh nuh ylhPnfu g
# WhnwmiHThigdh v hludh lcytx
# ht
#
# iter:13199/20000 loss:4.75322151184082
# generated sequence: Wl
#   hai h,  hl  hh wh'  ha Ahl  ha  ha  hh Iha :hs kht  hU gha ,hh  hh  ha fha  haauh. Shr mha ghd
#
# iter:13299/20000 loss:4.829684257507324
# generated sequence: Wde
# in iAn oho
# d: yul mh. Srlc :k yy w,d qh;' Bnt hdE Iur ton sTla,dT as. .p Eedc wdo iwo pdE gf f
#
# iter:13399/20000 loss:4.549388885498047
# generated sequence: Wehotehosdhosehosnhoothos hosshonthssrhosthosAhose os
#  oiehontho!ehos yosthorw oi.hosw osehosnhor. os
#
# iter:13499/20000 loss:4.833425998687744
# generated sequence: WIen cen
# lnrTen  en  fn den den  bn lonncon  en  ln vsn d
# n gen  ln  en genI on fan. an Lon son vln
#
# iter:13599/20000 loss:4.782162666320801
# generated sequence: Wt pis n
# fe rs wOntniteMpd ,AblLatohEr ,UfomatfN
# r, oto.lrowiwfintohitt wf hlwc rnsRaut aso mr c:s dk
#
# iter:13699/20000 loss:4.837948322296143
# generated sequence: Wk
# vaeLoberoBevo,efoledone ooe olean,e;n~eRoaeboIedoueoo;e!:.e naeioteudde
# oielytegoheroieOaaeloae om
#
# iter:13799/20000 loss:4.713736057281494
# generated sequence: Wims tos uos ahs eos mas aos ,Us nfs ehs ehs has hos yas ras pas cns yos rhy mos aos oos aos das dhs
#
# iter:13899/20000 loss:4.724881172180176
# generated sequence: WooEi.t o
# noovhriotcyg- h
# O win oIt
# oos votWiatwonruh,n)wOkEoorb,risaetPhot opMLiDghponuhin inrGiog i
#
# iter:13999/20000 loss:4.909348964691162
# generated sequence: WAd  Mso iuo ido idy Owo hi  fpI ido buw ?uo bs
#  is
#  Is
#  cmj nsf lss SsA
# sy sde Kio iKo un  dsl mDy
#
# iter:14099/20000 loss:4.7968878746032715
# generated sequence: Wt cas uus,disAowsidas aty gus ais ous ous mAs aas dus:u
# s uuskdUsonus d:s dys otsSous i
# s K
# sSdbs m
#
#
# iter:14199/20000 loss:4.851093769073486
# generated sequence: WdeomdnshCiso,tnhdwOh,BthdEvkefuudnTYdm;Ahty.:,sh.ew agf,ddeuIevoftnifrt,yeg
# ,suL
# tsMdexurew?egPodZe-
#
# iter:14299/20000 loss:4.680292129516602
# generated sequence: W tlYhhdohflYhibehtlu yoohtlohteodNkl;
#
# ohheThABnhrlohponh
# prhrsoheInh:lsh:nyhtf
# wyl
# hrllwtCokhlrhild
#
# iter:14399/20000 loss:5.0769758224487305
# generated sequence: W c kto mth sSt -tT ItN mti utR Ltt yts
# mM ati ZtJC
# ti yt. FtG nta  ta
# tu stt dt. Ctw eti  te st,uU
#
# iter:14499/20000 loss:4.640870094299316
# generated sequence: Wse. TTuudrnnOLnohrd,onr
# hhllwmI hpnooccoRtI f,blsch NrnotIn,lIns:tll unCdWnmhaes d,u t, baIh\bnlrrno
#
# iter:14599/20000 loss:4.698322296142578
# generated sequence: Woo eurrendmegfEeopmeuneeNlmeccleis:eoReenrienrheoreeorwenrheon.eErieinBeos:eisyenr:eat oy deotheirAe
#
# iter:14699/20000 loss:4.656830310821533
# generated sequence: WoGoer oer werhoersoerfyernners urupemmaer
# erg urtwerguerwoerR'er oer oe.g
# er oerwwerbanrnuerBiercoe
#
# iter:14799/20000 loss:4.733452796936035
# generated sequence: Wt
# ieooryoonyooisoidhooi:ooBiozieooneooTeooreooceoogeonreoogeooiuoore.oreooWuooniooiEooeuoId:oo;unodd
#
# iter:14899/20000 loss:4.9452056884765625
# generated sequence: WomutUy tnl toy tr!rtoe ty
# itE Rtae te ytwN tdN tCEpt
# O
# tT, t:d,tn kt: ,tnlNtlAwt?
# tbeitDlrtoeetw It
#
# iter:14999/20000 loss:4.7528204917907715
# generated sequence: Wot,
# tio,t?evtdanmra pahOttb RlyubiAStgontSa dhoehda dhgRtrevm-anansutparhgbymIatmn, otovt:atatewdIof
#
# iter:15099/20000 loss:4.648472785949707
# generated sequence: WwisunuwSna,
# nuidhum:nasenecfn kIn'U
# nbR nyAhna.
# nu,:nmsUndoSnec,nw,
# naS
# nLoknyc
# nd bnu snautbewsndyA
#
# iter:15199/20000 loss:4.375035285949707
# generated sequence: Wle ros Rol hss soe pMe dLH psirrSe fne uL  nvH ya- los ran bne bwm a'e rse on  oWiU,Te dw f^ud o
# s g
#
# iter:15299/20000 loss:4.522956371307373
# generated sequence: Wee pnesouee besodefol.s Aes Shs ues y
# afL,sanes nesInesLresathsbnes
# ye oresAne
#
# :hs fes lesatesoneer
#
# iter:15399/20000 loss:4.4520673751831055
# generated sequence: WN
# andhandocnwfToe,anerwoueanTE'pt
# A iw
# AghntowmIrwanotar:eesdempyaankhuwphEothanChar4LaniDsnSi-
# nFan
#
# iter:15499/20000 loss:4.753461837768555
# generated sequence: Wyotr: arh  rls dE iraFerd dg' uriw rn drh d', drC  rO sr terr  rl  rs eropRr srr'  rasmr;  rahdr, Er
#
# iter:15599/20000 loss:4.85493278503418
# generated sequence: Watken ken CenySDn odn Ien,!
# n sen hen pEn wenle;n ten
# f.n men ognnoun
# en dendeIn den een een ten be
#
# iter:15699/20000 loss:4.88434362411499
# generated sequence: Wun soosuR  uno uie tmo lt  s:oAain tnn up Chin wme bo dim  an  at  aC  gon umoEut ukto atl aiPcatn ,
#
# iter:15799/20000 loss:4.699038505554199
# generated sequence: Weyso isi edt eeT bsa Rso hs  wsa esa psi ysa fsa csN :so 6st ms les, rso ws; wst Rsulesi rs  wsi vsy
#
# iter:15899/20000 loss:4.46499490737915
# generated sequence: WI ra HDa bro wra pra;nrx gra cra;:re sramera Ora vra hra orl
# sra ssamlra sraairr sra mre wra mra Irb
#
# iter:15999/20000 loss:4.512277126312256
# generated sequence: Wo gow kih .ay Ohy ach dKw shh mh
# tafitnr
#
# ABw arg sh, urheirs wrN ztd ar[e A.oLhe ,iw aso Ial TDh an
#
# iter:16099/20000 loss:4.366130828857422
# generated sequence: Whimhs
# uis
# idde:OsR asatdseuns
# liseicsSigshins
# xhsimeseons
# poteins
# ivsip'se hs
# tesVics
# AasaOasavIs.i'
#
# iter:16199/20000 loss:5.1411848068237305
# generated sequence: WMKme pAe sfe Aar TceN
# ve twe;har nyy mme tUe
# AvelAer
# Knelt,hS,wer celhre.fdd nsD Fte iy. wnr sbelo~e
#
# iter:16299/20000 loss:4.523029327392578
# generated sequence: Wei  e
# i eti eei ee  ee  eii et
#  eo  ed  ed  ee  edr et
#  e!  ed net  ejS edN esi eoI eei enf edo eo
#
#
# iter:16399/20000 loss:4.927928924560547
# generated sequence: WeeRTnow neW
# te@ no
#
# nlOR=ed neYBnulIno nneb
# nochnom
# not
# no mnod
# notinsD nelrnec2ne tnor noG n.idnoh
#
#
# iter:16499/20000 loss:4.701333999633789
# generated sequence: W!Ow,am.:yIwnC Noo:hSLEEndavnd fhoNynas,
# mWpnp
# mhdoI dIpdd BihashbeRBItynOo,
# dopnorn,orenbaccmywhd nn
#
# iter:16599/20000 loss:4.408872127532959
# generated sequence: Wegasnnac,.a eoadl:a boao.eaw?oarlnanleaselacuiat,eaguoas
# Iar'lat sauenaneualfCav
# OatTUa ulamytasl.ad
#
# iter:16699/20000 loss:4.5826311111450195
# generated sequence: Wy n,ed de uae thl inw tae B.n fye qOe ba, mPe toe al, buy w
# e,ume leI ale ign Can Sae ull Hik .,e! y
#
# iter:16799/20000 loss:4.569890975952148
# generated sequence: W,oamaryCs lhsNy;s acs o:s chs Has rhs ths rds lts Ths busyOAs
# lUs yNsiXddnels KasiisGaEhs ths t!shL;
#
# iter:16899/20000 loss:4.540762901306152
# generated sequence: Wibf Haiaots esd Sd iret r
# dinep O
# T :
# skIe safo y
# ires ux;s ,
# T y,f ,
# cmkEi er  ,e
# Ies Fds  h
# t g,
#
# iter:16999/20000 loss:4.506436347961426
# generated sequence: WRIophionheo higtneo hithh
# g,heonhionh
# f hcobh
# ophiC:h
# s hom hioth:o hionhiolhmowhhu hroch
# uOhionheou
#
# iter:17099/20000 loss:4.677323818206787
# generated sequence: WgIv
# r:!
# l b
# , s
# d anrs
# , N
# , Caf n
# ToM.r I
# B n
# d p
# w int c
# l P
# , b
# r y
# , '
# diw
# r u
# r f
# ir
# in
# t p
#
#
# iter:17199/20000 loss:4.331188201904297
# generated sequence: Wpe nau yaf sat dat maI Fal Iat lau lar mat dat nak oab haf tat tas las ian lap Hat :al iaah,ag mat t
#
# iter:17299/20000 loss:4.697676658630371
# generated sequence: W bls bsr m:s ted s
# G aen yes yh, tPs hUa cus.rea wef bHsr,
# y dNe wev Ienitus bes wef wes w;A walm en
#
# iter:17399/20000 loss:4.445221424102783
# generated sequence: W solau; at, at
# Tart'anl ame an,Tact at
#
# at,
# anepat
#
# amL
# a:e aot amy ane at
# Tar
#
#  vy at.
# ade au haue
#
# iter:17499/20000 loss:4.470865249633789
# generated sequence: WUe ws'tAhe he lGfe whe Ihe dRi ,Oe lem;lwe Lrethne hhe ,he hheel
# eliherd,e
# he bhe m,e ghe l4e
# he w
#
# iter:17599/20000 loss:4.311248302459717
# generated sequence: Wc
#
# U tld bod Ath tth gch Aib bamg
# in tlP ayU Ahourpw tur MLI Aso tph tloetS  tfw Nto lid fly tlU tid
#
# iter:17699/20000 loss:4.355391025543213
# generated sequence: WaId
# :ydT hd
# unlm
# rrc
# WdRyynnlann sntnvy
# y
# dE' nd
# WdA
#
# dR
# Kd,asdDu
# dM
#
# ncyu sasl ghdM' d
#
# ShTannd:
# hl
#
# iter:17799/20000 loss:4.473936557769775
# generated sequence: Wh,laiyl  falnSl  tl n,lfDIl fil n,l  tl nilfnClsrrl iml  fle tl  blnnBl  bl  il.i
# lenUl  bt rel  fl
#
# iter:17899/20000 loss:4.436385631561279
# generated sequence: W asoe Non soe so1 so
# Asoc soN souuson ,oU :ho  ob  rn sow soe !'
# Ssoe soe ipn  onlsob Lon soN uon so
#
# iter:17999/20000 loss:4.324680805206299
# generated sequence: WhersC
# m ais ae,'Wa fgef at vin
#  uc hnt, fe sm
#
#
# inA yo,iue  t-,'MtHseawhne
# find Otrh:e,h:t
# Mer
# UEI l
#
# iter:18099/20000 loss:4.519710540771484
# generated sequence: Wy w C h d con Wit quEysrftk
# el,ditoul hin hlk4, cKy
# stL
# igsWsty
# plp:E urnpy
# U h nrp F yhothiiczUd mu
#
# iter:18199/20000 loss:4.634426116943359
# generated sequence: Wy imn iys inu idh ie  iru ig' ind id, ilr idu ir, in, id  iru ivk in: il, ifu isr inM inl ilf idg id
#
# iter:18299/20000 loss:4.544753074645996
# generated sequence: Wuyam naL saaRdee nhe ,We yan dre wah wee Mie fso kar iah Hah whe tda ghe wRh leh whe dfe Ile nee wIe
#
# iter:18399/20000 loss:4.2176666259765625
# generated sequence: W il prrw hiy srt yF uh? do'lOeit oid opt liiden fhs nor ter thr: uug hh IoG Deit bipceit Im voit fiR
#
# iter:18499/20000 loss:4.63826322555542
# generated sequence: W?A wrt yrt srt vrt frt Irt ort lrt vrt drt crt Irt ort ur. rrt ort uyt hnt rrt crt nrt crt vrt ort m
#
# iter:18599/20000 loss:4.645042419433594
# generated sequence: W t in bln hie boe bon  un l,n hin sin  tn gin din rin  sn don Win Tmn EWn  pe t'n bin tun  en  fn um
#
# iter:18699/20000 loss:4.5174336433410645
# generated sequence: We,,vTcsigg
# llrnlye lIdovYWR,l bo lc he aw AtldX ?inS
#
# nogaovee. sdO IE.Aeu lCinnJ nl
# T, R:gy4n, he'
#
# iter:18799/20000 loss:4.015665054321289
# generated sequence: Wog ndhirn::W_,ibRh npiUod;om,
# 'o
#
# muES nd 'n:
# chns chh fuocfpse;l rAd
# KnL BRre tsoom sec,. afainr sE
#
# iter:18899/20000 loss:4.061892509460449
# generated sequence: Wo:'
#  tt, be; wI
#  v,
#  arl mr
#  wl; rri st
#  aun Eir thS col b'B dg
#  ray wj
#  vas Eas tN
#  wtk tdh lid caR
#
# iter:18999/20000 loss:4.3361992835998535
# generated sequence: WetavrtlyktamstaIftabdtam$tah:tamstashtahrtIeotayOtan tuuvtavsuam?taNftamftlh tamstas'tapRteh tahytas
#
# iter:19099/20000 loss:4.531205177307129
# generated sequence: W tLr ter tar ghI tnJ th  te' tan ter t,r ter bur tha tha th, tho tii ter chi ter lha tm, tar nel whI
#
# iter:19199/20000 loss:4.38470458984375
# generated sequence: Waanyay walsial uawwhal tacsralviobotaf lag tabDdv
# GharFCawyeanfFals au sab!lan taprNan taW sar nats,
#
# iter:19299/20000 loss:4.5239996910095215
# generated sequence: Wanhf mhZr her hey hmd hdd vntiheusGet ecr het heo harNIet heg herhhe; hrr her har hUd h.f her hed he
#
# iter:19399/20000 loss:4.124063968658447
# generated sequence: Wo to, ati gii nor hin mir YtB erF gis tos  vd tis Cif on, an, nib isf tos tii ml; tuf vod nYs nou vi
#
# iter:19499/20000 loss:4.514094352722168
# generated sequence: We sne roe loe boe k,e -oe moe ?oe:fo; sne bal soe moe yoe ho' ane noe yh. goe dainrIe roRI,
# e whe wo
#
# iter:19599/20000 loss:4.78478479385376
# generated sequence: Weminl anl hel aml gel mEl h
# l m?l bil mil yil dil gul hyl mdl Eal hul hil RTl f'l til SFl hil uil ut
#
# iter:19699/20000 loss:4.442355155944824
# generated sequence: W:D nso,nsat
# ss nsa nsognsacisithso nso,Isab,sabnsk nIa ts! nsagnsawnsafnsannsahnsamnsifnsat
# sai'samn
#
# iter:19799/20000 loss:4.5423054695129395
# generated sequence: Weo scoje
# o pooRIsothwoyeoo wfo cyo hbochhoyhioheaon lovuoovyvosl
# oH:FoAleotheovEeoshaothCd puopeEosy
#
# iter:19899/20000 loss:4.3668317794799805
# generated sequence: Wh irceec te  oe heel sek fe see meePw,eu oe  cen bedrle. tei lC fhe  tec teO kdl ke uteN te  he ,
#
#
#
# iter:19999/20000 loss:4.365981101989746
# generated sequence: W Il irT Rdl wi
# V:ch Ii
# C h
#
# di
# ori
# GET
# AdieoUd
#  El
#
# r
# Uit
# Aup
# ,dse re
# O,
#
# C?.
#
# Ai
#  dil,uk
#
# iratirut

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
all_losses = [loss.item() for loss in all_losses]
plt.plot(np.array(all_losses))
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# Wre
# sAd
# vusd tEy
# hi
#
# EA.:riAnfiSohim ci
#
# iy
#
# or
# yI,
# Wti
# Yml
# I sT ir
#
#  rdWis
#  filoie
#  ciyorrltwila f
# Ldiltul
#
# wihoci
# oJs
# I t
#
# Hsi wy,
# yE
# rCll or
#  Oi
#  Iiatesl ir
#  Iimoir
#
# 'I
#  hi
# dPC
#
# si
#  rm,o'd
# OIs sdi
# :SyM kiStim
# :ri
# for
# NRe
#
#  h
# AQi. riwoWiltki
#
# os
#
# ri
# ,rilewOl
# gibeN?OWdhw w,
#
# ss
# NHr: Ps
#  wimaiiO Pi
# Ksig fi
# Hiy
# d i
# tiv
#  moEgmh
# W ISoAi
# TOmmo m
# Cvmitil
#  I,
#  is
#
# ,
#
# Bsd
# Ior
#  pi
# thi
# oii
# Tor
#
# Tic dh
# C,,
#
# s,
# tsig iE
# asi
# csi
# Kg: tI,
# :fl. rilobiO h.
#
# ou
# l r
# WGe
# AgoM Pi
# lw:
#
# r.
# i,E:e A
# Rve
# AIu
#
# gh
# tNl:
# PA
#  di
# TIE aiv tIl;
# w
# Tfrlerd
# Evi
#
# li
#
# il
#  ciEB-k.
# #,
# TudQ irradipaii
# tficoISt ir
#
# IE.
# yi
# GII
#
# sec Se??

# %% [markdown]
# ### Method
# I employ a similar method to the original rnn we implemented to predict the next character. The only difference is that I used the stochastic gradient descent optimizer.
#
# ### Evaluation
#
# Compared to the adam optimizer, this a poor choice. The metric I use to evaluate how sensible the output is by seeing how close each part of the generated sequence resembles words in English. Since the output was mostly a bunch of scambled characters that had no semantic meaning, this optimizer did not do a good job.
