# %%
import string
import random
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### Prepare for Dataset

# %%
all_chars       = string.printable
n_chars         = len(all_chars)
file            = open('../Data/shakespeare.txt').read()
file_len        = len(file)

print('Length of file: {}'.format(file_len))
print('All possible characters: {}'.format(all_chars))
print('Number of all possible characters: {}'.format(n_chars))
# Out:
# Length of file: 1115394
# All possible characters: 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
#
# Number of all possible characters: 100

# %%
# Get a random sequence of the Shakespeare dataset.
def get_random_seq():
    seq_len     = 128  # The length of an input sequence.
    start_index = random.randint(0, file_len - seq_len)
    end_index   = start_index + seq_len + 1
    return file[start_index:end_index]

# Convert the sequence to one-hot tensor.
def seq_to_onehot(seq):
    tensor = torch.zeros(len(seq), 1, n_chars) 
    # Shape of the tensor:
    #     (sequence length, batch size, classes)
    # Here we use batch size = 1 and classes = number of unique characters.
    for t, char in enumerate(seq):
        index = all_chars.index(char)
        tensor[t][0][index] = 1
    return tensor

# Convert the sequence to index tensor.
def seq_to_index(seq):
    tensor = torch.zeros(len(seq), 1)
    # Shape of the tensor: 
    #     (sequence length, batch size).
    # Here we use batch size = 1.
    for t, char in enumerate(seq):
        tensor[t] = all_chars.index(char)
    return tensor

# Sample a mini-batch including input tensor and target tensor.
def get_input_and_target():
    seq    = get_random_seq()
    input  = seq_to_onehot(seq[:-1])      # Input is represented in one-hot.
    target = seq_to_index(seq[1:]).long() # Target is represented in index.
    return input, target

# %% [markdown]
# #### Choose a Device

# %%
# If there are GPUs, choose the first one for computing. Otherwise use CPU.
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)  
# If 'cuda:0' is printed, it means GPU is available.
# Out:
# cpu

# %% [markdown]
# #### Network Definition

# %%
class Net(nn.Module):
    def __init__(self):
        # Initialization.
        super(Net, self).__init__()
        self.input_size  = n_chars   # Input size: Number of unique chars.
        self.hidden_size = 100       # Hidden size: 100.
        self.output_size = n_chars   # Output size: Number of unique chars.
        
        self.hidden_layer = nn.RNNCell(self.input_size,self.hidden_size) 
        self.output_layer = nn.Linear(self.hidden_size,self.output_size)
    
    def forward(self, input, hidden):
        """ Forward function.
              input:  One-hot input. It refers to the x_t in homework write-up.
              hidden: Previous hidden state. It refers to the h_{t-1}.
            Returns (output, hidden) where output refers to y_t and 
                     hidden refers to h_t.
        """
        # Forward function.
        hidden = self.hidden_layer(input,hidden)
        output = self.output_layer(hidden)

        return output, hidden

    def init_hidden(self):
        # Initial hidden state.
        # 1 means batch size = 1.
        return torch.zeros(1, self.hidden_size).to(device) 
    
net = Net()     # Create the network instance.
net.to(device)  # Move the network parameters to the specified device.
# Out:
# Net(
#   (hidden_layer): RNNCell(100, 100)
#   (output_layer): Linear(in_features=100, out_features=100, bias=True)
# )

# %% [markdown]
# #### Training Step and Evaluation Step

# %%
# Training step function.
def train_step(net, opt, input, target):
    """ Training step.
        net:    The network instance.
        opt:    The optimizer instance.
        input:  Input tensor.  Shape: [seq_len, 1, n_chars].
        target: Target tensor. Shape: [seq_len, 1].
    """
    seq_len = input.shape[0]    # Get the sequence length of current input.
    hidden = net.init_hidden()  # Initial hidden state.
    net.zero_grad()             # Clear the gradient.
    loss = 0                    # Initial loss.

    for t in range(seq_len):    # For each one in the input sequence.
        output, hidden = net(input[t], hidden)
        loss += loss_func(output, target[t])

    loss.backward()             # Backward. 
    opt.step()                  # Update the weights.

    return loss / seq_len       # Return the average loss w.r.t sequence length.

# %%
# Evaluation step function.
def eval_step(net, init_seq='W', predicted_len=100):
    # Initialize the hidden state, input and the predicted sequence.
    hidden        = net.init_hidden()
    init_input    = seq_to_onehot(init_seq).to(device)
    predicted_seq = init_seq

    # Use initial string to "build up" hidden state.
    for t in range(len(init_seq) - 1):
        output, hidden = net(init_input[t], hidden)
        
    # Set current input as the last character of the initial string.
    input = init_input[-1]
    
    # Predict more characters after the initial string.
    for t in range(predicted_len):
        # Get the current output and hidden state.
        output, hidden = net(input, hidden)
        
        # Sample from the output as a multinomial distribution.
        predicted_index = torch.multinomial(output.view(-1).exp(), 1)[0]
        
        # Add predicted character to the sequence and use it as next input.
        predicted_char  = all_chars[predicted_index]
        predicted_seq  += predicted_char
        
        # Use the predicted character to generate the input of next round.
        input = seq_to_onehot(predicted_char)[0].to(device)

    return predicted_seq

# %% [markdown]
# #### Training Procedure

# %%
iters       = 20000  # Number of training iterations.
print_iters = 200    # Number of iterations for each log printing.

# The loss variables.
all_losses = []
loss_sum   = 0

# Initialize the optimizer and the loss function.
opt       = torch.optim.Adagrad(net.parameters(), lr=0.005)
loss_func = nn.CrossEntropyLoss()

# Training procedure.
for i in range(iters):
    input, target = get_input_and_target()            # Fetch input and target.
    input, target = input.to(device), target.to(device) # Move to GPU memory.
    loss      = train_step(net, opt, input, target)   # Calculate the loss.
    loss_sum += loss                                  # Accumulate the loss.

    # Print the log.
    if i % print_iters == print_iters - 1:
        print('iter:{}/{} loss:{}'.format(i, iters, loss_sum / print_iters))
        print('generated sequence: {}\n'.format(eval_step(net)))
              
        # Track the loss.
        all_losses.append(loss_sum / print_iters)
        loss_sum = 0
# Out:
# iter:199/20000 loss:3.347846031188965
# generated sequence: W_u rAtryt t
# t.3 t
# r U'hees'oudsm Nsnelrnomeeyp  ,rdseNTaaYgnIsi yenliTykns hoyau:dib  I an,hnM.btihp
#
# iter:399/20000 loss:3.1646182537078857
# generated sequence: WVurvats l, paFoefWUOeetrwomnineac -ToTr
# 'yuih twDrg' upt,mt lofyIeh ae aYern?diarcou: ss, wgrs
# aiasv
#
# iter:599/20000 loss:3.0493030548095703
# generated sequence: WTPn ini ou sonf uku y niArsbdnw gi 'o Ih shidh swash h-yr aot wng sof d ,ora yeWduroueaydFk
# llifhrnr
#
# iter:799/20000 loss:2.9258735179901123
# generated sequence: WUf
# onume c
# tondi atds nhelen. me ek ae t nne,e , ao oh Node ta aNd rIhehcol ,uor mof step atat,p
# tnn
#
# iter:999/20000 loss:2.8332104682922363
# generated sequence: Wurirhe th thrswiwtdrahesdyrrnchald Re simed piisr tivt l, ii  lirtshe s hon.
#
# :aant
# ?aI yitfe lho; k
#
# iter:1199/20000 loss:2.783787488937378
# generated sequence: Winsin,tI
# mekt
# dc,!
# h
# rw
# ,ol tatheh cht tahSbel  houu ls doe ahe eawf,ame:
#
# gho aoedFse ue ree thriaf
#
# iter:1399/20000 loss:2.718191146850586
# generated sequence: WVyr geathl krlt, foe beptharsrre
#
#  ilecenr Ee ng hows Yherl' tng
# onwd saol Jos, Reile Whfb l thel k
#
# iter:1599/20000 loss:2.6726462841033936
# generated sequence: Wwktr aa 'lg dast oid  uoine OhAan wher aos theren, aeywtrdts .end ;eloy simkd sinsis mossnseggenu so
#
# iter:1799/20000 loss:2.6283986568450928
# generated sequence: Wynher, mrge yhdn bruttes aaiy
# o fasIeoo' inoc aoyrwdT mipga;e,
# 'amg ouo d kibet nlr fouwheye
# ss on?
#
# iter:1999/20000 loss:2.621575355529785
# generated sequence: Wamem hety phld cont
#  meli/K
#
#
# DIK
# CORANI
#
# DWGDAAKSULE BNceC
#  he  wiw aoics you mnd bnPs be;  yooh  e
#
# iter:2199/20000 loss:2.59393310546875
# generated sequence: WVrala uh tane Hin tho styaupos more to shlatn ll's rokt wite re pite nt reou,
# ?hrr su bei.h
# Thlin li
#
# iter:2399/20000 loss:2.573881149291992
# generated sequence: Wroro mgy loud rove oon hecs tot yice hasojfr noous moiceeL?.
# Maf AheO salNoNy AF,t: eld f-olvI Tongn
#
# iter:2599/20000 loss:2.5523335933685303
# generated sequence: Wnan he!
#
# IGbm Lnord
# Bne ?oame fee oouwe; lamh btals tice
# 'ne dery im thial welun orule C noue ie aat
#
# iter:2799/20000 loss:2.5357742309570312
# generated sequence: W riu, nove tzat hersof ar trco sinl !ome tofaf ifalt ne biale that the st ooblare seqmes to? tit  he
#
# iter:2999/20000 loss:2.509614944458008
# generated sequence: Wy eayeerr bo dsnoe; ieo gtd noud isd blefru oF hetindr,g
# rpareatf is ad mets thy se are-by thers,suo
#
# iter:3199/20000 loss:2.506580114364624
# generated sequence: W.
#
# fUINANN:
# Hors lneb tir ilg thal, be be fand thas, Ocs yac hhat hne priea-trvbs wadu neykuc.
# KIN G
#
# iter:3399/20000 loss:2.4948837757110596
# generated sequence: Wt yaugmAle
# nred, tnaplree ss toue f, bind satie p ihen wed miseind
# Sood tfos buos ;edvete .
# iR br A
#
# iter:3599/20000 loss:2.4846222400665283
# generated sequence: Wmeme, m'mctetIamy gamir nhe untn hel,
# be mad dounnee os mous alr qsates medrasd -an t ent iu hewpee
#
# iter:3799/20000 loss:2.4694783687591553
# generated sequence: W!lL he, tonte avy keow Pat. Bouseis butis.e
#
# ICUCCUHTNRISOL DW:
# ThDY  hauetirt withosd tincrelit nr
#
# iter:3999/20000 loss:2.4519917964935303
# generated sequence: Wwaevetd wingews
#
# [aRUEIN:
# Hand'd cowde, ' soorn, we go lanl dmece.
# DSealr RuiF ne asoH m oechndI mif
#
# iter:4199/20000 loss:2.455568552017212
# generated sequence: Wthe they ine nparsinr wonrsen, sfanmis anrove D oilo ?it ai honQ, me ghd bin oon,
# Il he.
#
# hEn HyE:
# T
#
# iter:4399/20000 loss:2.454763889312744
# generated sequence: W te citnthist he hvptar nhat bof yok har ntbf sorss lis hnl Irtors ninhud: ar careathne io poueTd,
# N
#
# iter:4599/20000 loss:2.4474287033081055
# generated sequence: Wand, woin nil, ty louplry y uusleg.
# SFowPGLEMIOM
# ARMEI:
# ot wacnat seer-sha-.
# I&SL
# EUFNANNTL A Kut:
# C
#
# iter:4799/20000 loss:2.421072483062744
# generated sequence: W,o sige an mryyom westh fyoO kn nou?, IF gowice pie dith werif wsme kamprpafd giohs math mesd ald an
#
# iter:4999/20000 loss:2.419351816177368
# generated sequence: Whhor whlnnt, fad tirit s. momt iis reall ,oo to nur-Im: por,
# Bnd thal yout meot sou dols, alind ne f
#
# iter:5199/20000 loss:2.4144949913024902
# generated sequence: Whar areed,
# GI:
# LfCGMOELTMz:
# Aith
# Tir ts soue thiw shoo thy kep! I aot, bafr,ee wead hos ho
# 'rs sorla
#
# iter:5399/20000 loss:2.411214828491211
# generated sequence: Whee be
# trkyn sximeu;
# dowir, The,,
# -stot teoy ind boy opth, !aval, barluce ryObws red.
#
# PRMYOR:
# On;r
#
# iter:5599/20000 loss:2.4017629623413086
# generated sequence: WSate tard gis yod Te kim ;echi do keas 'tit?
#
# AOAEELT:
# Ie rkeargipteasd yore
# :ecove, she thenee.
# Sam
#
# iter:5799/20000 loss:2.417011260986328
# generated sequence: Watoo t mov wot ind you fub mamts, tha? oou therbyethe parcmelsopltaeas,
# Whennof toersangorbpoame gua
#
# iter:5999/20000 loss:2.396977424621582
# generated sequence: Wm ny
# iMs :uthe the thuve's lor wovy wo'd af coun tht andchamdne fundst rito no thach olky yr freadet
#
# iter:6199/20000 loss:2.3936002254486084
# generated sequence: Wat, eid siagsenk, vet ho hor fnafy hhalrasn
# &uthace then so piane witt troothe Thou to th t yarreld
#
# iter:6399/20000 loss:2.3835816383361816
# generated sequence: WMars.
#
#
# IlRU	IE:
# Ot aullos, I anit tere tl thaag.
#
# Has Io sipsorr doold
# ruth at whor mbys,
# MRpo gar
#
# iter:6599/20000 loss:2.366652011871338
# generated sequence: Wdt paat bime berdte thish in sor geror oat Yar, yon sant lhere andret-, woul ore frySnh nois taywo w
#
# iter:6799/20000 loss:2.3848233222961426
# generated sequence: Wh
# widvD! hor thow ?and y aretrtith fritlenot
# D:.Aom,
# Th ikriogs byoh butlo maewers theh! th, Ioll to
#
# iter:6999/20000 loss:2.3634626865386963
# generated sequence: W ay srid blad heilh feela
# han, an mat tent hethan tfau:
# Thd wiA theigd raindriins thoun th thinm:
# Th
#
# iter:7199/20000 loss:2.3712644577026367
# generated sequence: W
# CuIMGEY
# GOH:
# An. Aho  hill wolk iat,
# Is ha do ko sto nnmy hame ineinc.
#
# LZKECFRDFDLNDR:
# F berendre,
#
# iter:7399/20000 loss:2.3536672592163086
# generated sequence: Wy!r, le s rott ay on Ea cipeI ovetsr nort fomald you anye be rare, Ila te rappood sere?
# IWBlilley ue
#
# iter:7599/20000 loss:2.349518299102783
# generated sequence: Wis cioy ? nowes olous therca! bo; ous ewedl we oacou, iface tore hereln se?
# Weren ticly ey ptiAnd:
# T
#
# iter:7799/20000 loss:2.375053882598877
# generated sequence: Whamy Whey,
# ro-int? bf sterer.
# Whaod thr kloscGanfy hd laret ur cudlty, more siim?
# Mothit ta thO unea
#
# iter:7999/20000 loss:2.361905336380005
# generated sequence: Weles, ware th thene fbiss,sth, angande.:
# Oud ham mf yath nous.
#
# 6Oin u the orerogercond ar gericef-i
#
# iter:8199/20000 loss:2.349769115447998
# generated sequence: W0os ?out.:
# And woon
# Tneiloo
#
# Oo I po kevy w awmgriGle wiI Ahe wean. Goull, fothow unnd outhag tos se
#
# iter:8399/20000 loss:2.341693162918091
# generated sequence: Why
#
# uslryve thou e vosb oumend ichistish s piinesou wh ceelos thang.aL bwat Tse, pneilmed m in fyo f
#
# iter:8599/20000 loss:2.3457555770874023
# generated sequence: WGed out howher astse
# at mpdrelf
#
# YeKS CIRENENAS:
# Becand ald,
# SbEnd ilo phon touet
# Au , sEpinrey.
# Yor
#
# iter:8799/20000 loss:2.3490467071533203
# generated sequence: WK sapllretis?
#
# orde thinid arentk kangAW:
# Fole berismtere dor milll: bithe fould gat,
# Iod freepdewal
#
# iter:8999/20000 loss:2.3455376625061035
# generated sequence: Wiaggd,
# Sher whon, wag halle co nosd:
# woul reall klons dong sorcthil dith?
# yed Katisu ao , ou dort t
#
# iter:9199/20000 loss:2.3340542316436768
# generated sequence: Wn apid stath ywemy int foagpweve melugh in to bop.
# Whaed tha dano or satt.
#
# INLEUIE:
# I toplimeis int
#
# iter:9399/20000 loss:2.3256826400756836
# generated sequence: Wkenadn's tnose theld dud,
# on sal;, naeldengone,
# Whav,
# Wofde,
# Mhass ss etous lorThe aed sren
# ,ti hesm
#
# iter:9599/20000 loss:2.342506170272827
# generated sequence: Whar moy fa?g
# Tan ciPe;
# Aste youkef;
# ThS he ineag.
#
# IICKUSECIESRBATERCINWR:ABlo oowe ee if,
# Sorcofeli
#
# iter:9799/20000 loss:2.3246636390686035
# generated sequence: Whath be, -easke we the aat Mhangill.
#
# Huroud, Ihar bfare on Hy lale hinrost weores ree tes at baveli
#
# iter:9999/20000 loss:2.325207471847534
# generated sequence: WselHe f lat.
# -firy, af heven, youn..
#
# BACCEOACNNINTU:
# Kh mlbat at ous: aer thes owrese sr tore, dhil
#
# iter:10199/20000 loss:2.3301918506622314
# generated sequence: Wan pross chove,
# This bpoutn.
#
# NoUI WS:
# Aor his Ar thale' sal: buis thaNd, Mhapr wiine yhe dindn fouc
#
# iter:10399/20000 loss:2.316699981689453
# The foller yoal sook I po mhand, meol wlyou that izoD ckouco, d, me rira'djAng ho bnomkto s celB Dp
#
# iter:10599/20000 loss:2.3180973529815674
# generated sequence: Waige bmeod-s
#
# noO, Sranhers, Wokis rrand.'
# not wish uroe soke:
# Hesinm;
# Bf wod th is fure nren preacr
#
# iter:10799/20000 loss:2.328317165374756
# generated sequence: Wart merelr tat and gy cond y cerestthe ou -ithe sal',dcgpi, pomy, bogerin.
#
# DUlle mod ilg ant ase no
#
# iter:10999/20000 loss:2.3155806064605713
# generated sequence: WE is I correid 'r fo leebrengu, thin oIt ghel.
# Fbroy eat data.
#
# HURGINVOO:
# Whar nhes, ne anfergiprit
#
# iter:11199/20000 loss:2.3072290420532227
# generated sequence: W'y mear hinou hiy thet,
# Sht on coolm hit is youve
# OI
# I SI InOS'
# AWIEE
# DzNI N:
# Shea o d ats co thet f
#
# iter:11399/20000 loss:2.3091089725494385
# generated sequence: WD toor: the ao he the,
# Weom ind nin
# thaus amun the; ifrrtreve dy wink wound ows gt and he haven you
#
# iter:11599/20000 loss:2.319000005722046
# generated sequence: Wiid ut war !u s mo-pery ancelllmy gon.
# Whale, co loathas taKmen, thmu hore oad of the peinlcend them
#
# iter:11799/20000 loss:2.299777030944824
# generated sequence: Winr osdarlyot thesou, now fritee habe hie indistaty rin?
# Fhapnor padkindan;
# Aun chalats ane comh, th
#
# iter:11999/20000 loss:2.317744016647339
# generated sequence: WEe; by m axthem that spill merlimm.
#
# Plyve
# Ny:
# Normis.
#
# TRNBUN:
# Fmverse ure hout yar Ihtan anceroy c
#
# iter:12199/20000 loss:2.3040685653686523
# generated sequence: Wtee goull e bemy
# tine th ois tin thes bipe's dosilipg afde
# "l here,
# Anj hal aodld pame buge cath ker
#
# iter:12399/20000 loss:2.2962071895599365
# generated sequence: Wond the to hees:
# Ifon theve hes btenf ek?
#
# harlt fhet Lous, Lovor sleait warer hile:
# Apd thad dist t
#
# iter:12599/20000 loss:2.303912878036499
# generated sequence: Weat is ag arels forein-gSis lorpandourris.
# FRXHUk?
# HY hoNlsty:
# Aadil: cet mhint:
# Tseis, buns-lre, t
#
# iter:12799/20000 loss:2.2988452911376953
# generated sequence: WiWh p laugad senerenon puat the that old thaf,-yhis wores hibk,
# The I mipyry coullllwat, cnathas som
#
# iter:12999/20000 loss:2.3021562099456787
# generated sequence: WP deer ite ilr mame
# Tor ap ale,
# RIUTh OoCLLIER:
# Erthe nost sor, biingate sa nus lererc.
#
# RSOFGKRK I
#
# iter:13199/20000 loss:2.2958078384399414
# generated sequence: Wice woferes phives.
#
# QERANTORU iB nHDAn;,SMf paacine s, Loe--ood win comelgovug fathse kime fon hou,
#
# iter:13399/20000 loss:2.287645101547241
# generated sequence: Whi?
# AI Iok chnarin, sous dall.r
# Feamo juas Iey eils , mat ale inghe cochot sar fursenfean erodnon.
#
#
#
# iter:13599/20000 loss:2.279381036758423
# generated sequence: Wy qaninns ny ont toop hard'et yit? oumd, Thour and, ptot har, no ctory mry bekinf her ist'me oor sik
#
# iter:13799/20000 loss:2.2832202911376953
# generated sequence: Wap'll ha
# d'dere, werraats fullens pores you inkagtor s turta.
#
# AAANOOAS  Pead sur at theer hed thale
#
# iter:13999/20000 loss:2.292085886001587
# generated sequence: W.
#
# KKyLA:
# F wirs be o cuokn ut binkhee hatre; cus ne he breafes thk noo ftoy Yujt
# nof ap shiputhind
#
#
# iter:14199/20000 loss:2.2808468341827393
# generated sequence: WJuthile as I ound d; bevello
# Y; Frrentheu dod our'n ws ngbato
# Darishe gobe ir; some heis. ood swaya'
#
# iter:14399/20000 loss:2.287987232208252
# generated sequence: We predeto to; fout gos fitk thaid
# Corginis hyou ts emeanf.
# T Kole preinlor mad, eveist ta ashive on
#
# iter:14599/20000 loss:2.2830114364624023
# generated sequence: Whin, yourdantn oveal; whes youe Kfad ar be co vare di?t
# Sewathis dite sapr, hor snathes cbintirh tha
#
# iter:14799/20000 loss:2.2827887535095215
# generated sequence: Wt afd, Irho plolisd madd miy, be pakr, th ter dishe gut po cicevere he thad med, nousy, af woyow mau
#
# iter:14999/20000 loss:2.271285057067871
# generated sequence: Wtrware,
# Thim on wal able yolo's
# Bur amd C8acptI enbyit ohe loos.
#
# LERGAD,:
# Nos ag  oe'l wy ead anf'p
#
# iter:15199/20000 loss:2.262629508972168
# generated sequence: Wkith brimee ow cherlus dith ie the'.
#
# Tuavhan,
# Aed shearce;
# Coruthe sunounes at ar.
# Ted fom watn to
#
# iter:15399/20000 loss:2.263066291809082
# generated sequence: Whisge shin fram, ons t sher anme seed, ti' hoj thoy I demy ackelllle
# denerg wis inrishae navin,
# Yo s
#
# iter:15599/20000 loss:2.2767913341522217
# generated sequence: Wy ch aten.
# MRRinn LoRA'I Sr aon: lin the fyos:yas I fol soy ueakg tovbsest you withit, I areicy wily
#
# iter:15799/20000 loss:2.2701220512390137
# generated sequence: Wert wond, th! s, th sopn.
#
# STENDEN:
# Nhe hered sf ir bet hit! a joove haj wfook.
#
# LORKEO:
# Shal fooved
#
# iter:15999/20000 loss:2.2645838260650635
# generated sequence: Wurdiag shuy m baully urd yhe tfitlind
# Bate
# me
# The cold and Hnol are porcacasest dimese ds ikean, do
#
# iter:16199/20000 loss:2.262653112411499
# generated sequence: WERd And: wetd
# Sion benusit ve tino nes'l, on wore tha ceico bores, cuy ut the grous pninocst tsall
#
#
#
# iter:16399/20000 loss:2.2586750984191895
# generated sequence: WerrRa co hiths fme ry that mall.,
# Thes thare!
#
# IIAS
# AFALD: Ma lourud te vasnis se stour;
# WhaR. Ther
#
# iter:16599/20000 loss:2.25087833404541
# generated sequence: Whe;nd,, ve thy haplande in wiak me y aekend nead and seed,
# Bow on Ant, ghaing Vtithe cholht 0om'ilha
#
# iter:16799/20000 loss:2.2663698196411133
# generated sequence: Whal foon hathat dord lndell
#
# HI-d nfir mo pooris of bepereculn,
# To Ihes fomy sowpey blawd neag tupse
#
# iter:16999/20000 loss:2.2665884494781494
# generated sequence: When trteeterA chignnoI
# Wale and gaich of ei hean the gist rooy and
# Cuthald are out.
#
# SLRMDUPCI IEy E
#
# iter:17199/20000 loss:2.2714433670043945
# generated sequence: W 'enEtt ullewe thR Gummen
#
# ANEBGNINUK:
# Oo urst eame hime tor,
# On hee of y hatke slo mamton stoy the
#
# iter:17399/20000 loss:2.2438907623291016
# generated sequence: Whor drust'l virs? I berre?
# BwatM, Fmy blaNlat on surses
# ThastI bo douc, con,
# You sine heel te thy, l
#
# iter:17599/20000 loss:2.2639684677124023
# generated sequence: Whad aot oo what you fikf wief, bew
# Inde thor doupr' he thy thail sty, aim ty ay.
#
# WhaEk Cesbes I Dar
#
# iter:17799/20000 loss:2.251483201980591
# generated sequence: WeTlike nie tur onger-zist soush youm n's your CaIgh wlo bign'd,
# Th an, erat fereped wulk,
# Lound nou
#
# iter:17999/20000 loss:2.2421696186065674
# generated sequence: Wher sing,
# whr the, tson es, hand poot?
# And Thale thing un too y ouresn I, Hente herit, the lot satp
#
# iter:18199/20000 loss:2.263162136077881
# generated sequence: Whif fr vellre dn't dous
#
# Ke chant Iod th: hem, fer balg the fon thakp lood the dic, and hicht theo l
#
# iter:18399/20000 loss:2.2607619762420654
# generated sequence: Werus inder nom west beds aptowsam's dlagt,
# AEt blangey the doreunt and,anwensb hel,
# Gow telilmy-ond
#
# iter:18599/20000 loss:2.2474241256713867
# generated sequence: Wogeell cofest lachim
#  have, tt y sovete stals:
# Hatt ou srece hin!
#
# SVaUMIY: Hemesitthe
#
# Wellusas, do
#
# iter:18799/20000 loss:2.2477803230285645
# generated sequence: Ward wian of avears ope thar !rlome her wishou'd io d atw in alls me oll poud er tadom heRr meinhe wh
#
# iter:18999/20000 loss:2.264098644256592
# generated sequence: Wher goSks you ko dfot se nod pe, hais, eny: miad,,
# Thit thisc ie how, my und w hor, Phemere y hathev
#
# iter:19199/20000 loss:2.249026298522949
# generated sequence: W
# PUSaNA::
# He belles?
# Tala sithig a at uom thipeske lorte:
# Sith da hirst sfoy of huran,
# Fou so thew h
#
# iter:19399/20000 loss:2.245077133178711
# generated sequence: Whes waod Phate meree be for bere senzir;
# I lenerstor'd, puthis ino? Cleace fours and.
#
# BUUCESRYSTAA
#
#
# iter:19599/20000 loss:2.2434134483337402
# generated sequence: Wae pakne th'n I gere shihet, chink tonds the dote mect deeread
# Fors?
# ourke th irit thou theit
# sart
#
# iter:19799/20000 loss:2.251466751098633
# generated sequence: Wayen of,, the mamtha sord oo cher.
# IHew ar th arcit ot wis me arken
# kondt mato, I raishes I; I ky ne
#
# iter:19999/20000 loss:2.2372019290924072
# generated sequence: Whind ong.
#
# AROEGHSXWBNEE:
# Ko Vendishedpry
# Yor tfiks soult ipher eweet in peok the mestgeget tn ang t

# %% [markdown]
# #### Training Loss Curve

# %%
plt.xlabel('iters')
plt.ylabel('loss')
all_losses = [loss.item() for loss in all_losses]
plt.plot(np.array(all_losses))
plt.show()

# %% [markdown]
# #### Evaluation: A Sample of Generated Sequence

# %%
print(eval_step(net, predicted_len=600))
# Out:
# Wheth ereyou
# nather buoe ip wlas thave tham capgemprinondultadele,
# govengrtilet!
#
# IWGRMOUMA FhepI:
# On ul bavematl. Aul mofno areese-o apodd miRs aeve and badefer ingll!t ghe farjore I mame.
# Aat I stela ?iee geandingll?
# Ay ECrCADI ELEN
# BAOI:
# Fias not t oid, sthes ford, he coanth fropy ne cooferntor oot haig, losdessold,tr siang
# And afpmere bmes ar hagheh'f datleut mi ks whes.
# Thave mis ir nishswatchtryen cage nos in
#
# ieto, yows an aow fave simichet.
#
# PULEDNN:
# Tort youe flare, ast pave bor, her to'r thoursslse't chat!'y parwardarde, baond
# And RuA EINI M yuep andte hou 'sicesellls gores anke d ous

# %% [markdown]
# ### Method
# I employ a similar method to the original rnn we implemented to predict the next character. The only difference is that I used the AdaGrad optimizer.
#
# ### Evaluation
#
# Compared to the adam optimizer, this is an okay choice. Although the difference in loss between the baseline and this model is not a significant amount, we can tekk that there are more incorrectly spelled words in this ouput.
